# %%
import pandas as pd
import re

debugging = True

# %% [markdown]
# ### Load Stata Source

# %%
stata_file = open( "data/QprExport-2018.06.29.stata", 'r' )
stata_list = [ line.strip() for line in stata_file.readlines() ]

# %%
stata_list[ 0 ]
# Out:
# '********************************************************************************'

# %% [markdown]
# ### Load Pirl 'n' Parquet Names

# %%
pirl_to_parquet_df = pd.read_csv( "data/raw-pirl-to-parquet-names.csv", usecols=[ "PIRL_ElementNumber", "ParquetName" ] )
pirl_to_parquet_df[ "Pirl" ] = "PIRL" + pirl_to_parquet_df.PIRL_ElementNumber
pirl_to_parquet_df.drop( "PIRL_ElementNumber", inplace=True, axis=1 )
    
print( pirl_to_parquet_df.head() )

# get as dictionary: EZ!
pirl_dictionary = dict( zip( pirl_to_parquet_df.Pirl, pirl_to_parquet_df.ParquetName ) )
# Out:
#                       ParquetName     Pirl
# 0                       ObsNumber    PIRL0
# 1  UniqueIndividualIdentifierWIOA  PIRL100
# 2        StateCodeOfResidenceWIOA  PIRL101
# 3           CountyCodeOfResidence  PIRL102
# 4              ZipCodeOfResidence  PIRL103

# %%
pirl_dictionary[ "PIRL900" ]
# Out:
# 'DateOfProgramEntryWIOA'

# %%
for i in range( 5 ):
    
    print( stata_list[ i ] )
# Out:
# ********************************************************************************
# *************************QPR TEST AGGREGATION RULES*****************************
# ********************************************************************************
# cd "H:\Data Work\WIPS Test File"
# local cdate: display %td-CY-m-D date(c(current_date),"DMY")

# %% [markdown]
# ### Build Stop List of Translatable and Hideable Lines

# %%
hideable = [ "putexcel" ]
translatable = [ "local", "count", "replace" ]
translatable
# Out:
# ['local', 'count', 'replace']

# %% [markdown]
# ### Kill Multiple Space Chars

# %%
def kill_extra_spaces( raw_line ):
    
    # replace multiple spaces w/ just one
    return re.sub( ' +', ' ', raw_line )

kill_extra_spaces( "12  23  45               4 4 4 4 4        45 64 6  ASFD     " )
# Out:
# '12 23 45 4 4 4 4 4 45 64 6 ASFD '

# %% [markdown]
# ### Normalize Parenthesis

# %%
def normalize_parenthesis( raw_line ):
    
    # add spaces between parens and chars
    raw_line = re.sub( r'\(', "( ", re.sub( r'\)', " )", raw_line ) )

    return kill_extra_spaces( raw_line )

normalize_parenthesis( "//         putexcel M21 = (r(N)),    sheet(       `report' ) foo(`bar')" )
# Out:
# "// putexcel M21 = ( r( N ) ), sheet( `report' ) foo( `bar' )"

# %% [markdown]
# ### Normalize Plus Signs

# %%
def normalize_plus_signs( raw_line ):
    
    # add spaces between plus signs and chars
    raw_line = re.sub( r'\+', " + ", raw_line )

    return kill_extra_spaces( raw_line )

normalize_plus_signs( "count if ( ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==2 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==3 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==4 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==5 ) ) & `FS' & `total' & `prevpartdef'" )
# Out:
# "count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==2 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==3 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==4 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==5 ) ) & `FS' & `total' & `prevpartdef'"

# %% [markdown]
# ### Normalize Equals Signs

# %%
def normalize_equals( raw_line ):
    
    # reduce and add spaces between equals signs and chars
    raw_line = re.sub( r'==', " = ", raw_line )

    return kill_extra_spaces( raw_line )

normalize_equals( "count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==2 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==3 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==4 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==5 ) ) & `FS' & `total' & `prevpartdef'" )
# Out:
# "count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 2 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 3 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 4 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 5 ) ) & `FS' & `total' & `prevpartdef'"

# %% [markdown]
# ### Translate Conjunctions

# %%
def translate_conjuntions( raw_line ):
    
    # replace | with OR, add spaces between
    raw_line = re.sub( r'\|', " OR ", raw_line )
    
    # replace & with AND, add spaces between
    raw_line = re.sub( r'&', " AND ", raw_line )
    
    return kill_extra_spaces( raw_line )

translate_conjuntions( "replace age = age - 1 if (month(PIRL906) < month(PIRL200)) | (month(PIRL906) == month(PIRL200) & day(PIRL906) < day(PIRL200))" )
# Out:
# 'replace age = age - 1 if (month(PIRL906) < month(PIRL200)) OR (month(PIRL906) == month(PIRL200) AND day(PIRL906) < day(PIRL200))'

# %% [markdown]
# ### Translate Variable Declarations

# %%
def translate_variable_declarations( raw_line ):
    
    raw_line = re.sub( '^local ([A-Za-z0-9]{1,}) "', r'val \1 = "', raw_line )
    
    return kill_extra_spaces( raw_line )

translate_variable_declarations( 'local Adult "(inlist(PIRL903,1,2,3,4))"' )
# Out:
# 'val Adult = "(inlist(PIRL903,1,2,3,4))"'

# %% [markdown]
# ### Translate 'IN' clauses

# %%
def translate_in_clause( raw_line ):
    
    # WORKS: raw_line = re.sub( r'(PIRL[0-9]{1,3})', r'__1st__\1__1st__', raw_line )
    # WORKS: raw_line = re.sub( r'inlist\(', 'MATCH', raw_line )
    # WORKS: raw_line = re.sub( r'(inlist)', r'--YEP--\1--YEP--', raw_line )
    # WO$RKS: raw_line = re.sub( r'(inlist\() (PIRL[0-9]{1,3},)', r'1st:[\1] 2nd: [\2]', raw_line )
    raw_line = re.sub( r'(inlist\() (PIRL[0-9]{1,})', r'\2 IN (', raw_line )
    
    # TODO: call method that strips first char (",") from match string, instead of this kludgey workaround
    # SEE: Date Variable Declarations below for example
    # kludgey, but it works: replace " IN (," with " IN ( "
    raw_line = re.sub( r' IN \(,', r' IN ( ', raw_line )
    
    return kill_extra_spaces( raw_line )

translate_in_clause( "( inlist( PIRL903,1,2,3,4 ) )" )
# Out:
# '( PIRL903 IN ( 1,2,3,4 ) )'

# %% [markdown]
# ### Translate Date Variable Declarations

# %%
# declare month abbreviations to numerics as a dictionary
months = {}
months[ "jan" ] = "01"
months[ "feb" ] = "02"
months[ "mar" ] = "03"
months[ "apr" ] = "04"
months[ "may" ] = "05"
months[ "jun" ] = "06"
months[ "jul" ] = "07"
months[ "aug" ] = "08"
months[ "sep" ] = "09"
months[ "oct" ] = "10"
months[ "nov" ] = "11"
months[ "dec" ] = "12"

def substitute_months( match ):
    
    return 'val {} = "{}-{}-{}"'.format( match.group( 1 ), match.group( 4 ), months[ match.group( 3 ) ], match.group( 2 ) )

def translate_date_vars( raw_line ):
    
    # This line calls a function w/ the match object.  ¡Genial!
    # Here: https://stackoverflow.com/questions/17136127/calling-a-function-on-captured-group-in-re-sub
    raw_line = re.sub( r'local ([a-zA-Z0-9]{1,}) (\d\d)([a-zA-Z]{3})(\d\d\d\d)', substitute_months, raw_line )
    
    # Plain, w/o month abbreviation to numeric lookup
    #raw_line = re.sub( r'local ([a-zA-Z]{1,}) (\d\d)([a-zA-Z]{3})(\d\d\d\d)', r'var \1 = "\4-\3-\2"', raw_line )
    
    return kill_extra_spaces( raw_line )

translate_date_vars( "local begpart2date 01oct2017" )
# Out:
# 'val begpart2date = "2017-10-01"'

# %% [markdown]
# ### Translate "d( var )" to "to_date( '$date_var' )"

# %%
def translate_date_function( raw_line ):
    
    raw_line = re.sub( r" d\( `([A-Za-z0-9]{1,})' \) ", r" to_date( '$\1' ) ", raw_line )
    
    return kill_extra_spaces( raw_line )

translate_date_function( "( PIRL900 <= d( `qtrend' ) )" )
# Out:
# "( PIRL900 <= to_date( '$qtrend' ) )"

# %% [markdown]
# ### Translate Inline Variables

# %%
def translate_inline_variable_insertions( raw_line ):
    
    raw_line = re.sub( r"\`([a-zA-Z0-9]{1,})'", r"$\1", raw_line )
                      
    return kill_extra_spaces( raw_line )

translate_inline_variable_insertions( "( `partsplit' AND ( PIRL900 <= to_date( '$qtrend' ) ) AND ( ( PIRL901 >= to_date( '$begpartdate' ) ) OR missing( PIRL901 ) ) )" )
# Out:
# "( $partsplit AND ( PIRL900 <= to_date( '$qtrend' ) ) AND ( ( PIRL901 >= to_date( '$begpartdate' ) ) OR missing( PIRL901 ) ) )"

# %% [markdown]
# ### Remove References to "$FS AND "

# %%
def remove_ref_to_fs( raw_line ):
    
    raw_line = re.sub( "\$FS AND ", "", raw_line )
    
    return kill_extra_spaces( raw_line )

remove_ref_to_fs( "count if $FS AND $bcsvc AND $exitdef" )
# Out:
# 'count if $bcsvc AND $exitdef'

# %% [markdown]
# ### Create Stop List of _Proper_ Date Columns

# %%
proper_dates = [
    "DateOfProgramEntryWIOA",
    "DateOfProgramExitWIOA",
    "DateOfMostRecentMeasurableSkillGainsSkillsProgress",
    "DateOfMostRecentMeasurableSkillGainsTrainingMilest",
    "DateOfMostRecentMeasurableSkillGainsPostsecondaryT",
    "DateOfMostRecentMeasurableSkillGainsSecondaryTrans",
    "DateOfMostRecentMeasurableSkillGainsEducationalFun",
    "DateEnrolledInPostExitEducationOrTrainingProgramLe",
    "MostRecentDateReceivedBasicCareerServicesSelfServi",
    "DateOfMostRecentReportableIndividualContact",
    "DateAttainedRecognizedCredentialWIOA",
    "DateAttainedRecognizedCredential2",
    "DateAttainedRecognizedCredential3",
    "DateOfFirstWIOAYouthService",
    "CoveredPersonEntryDate",
    "DateOfBirthWIOA",
    "DateOfFirstIndividualizedCareerService",
    "DateOfFirstBasicCareerServiceSelfService1",
    "DateCompletedDuringProgramParticipationAnEducation",
    "DateEnrolledDuringProgramParticipationInAnEducatio"
]    

def is_proper_date( pirl_name ):
    
    parquet_name = pirl_dictionary[ pirl_name ]
    
    return parquet_name in proper_dates

print( is_proper_date( "PIRL900" ) ) # True
print( is_proper_date( "PIRL100" ) ) # False
# Out:
# True
# False

# %% [markdown]
# ### Translate !missing(...) According to Date Type: String vs Proper Date Column

# %%
def get_not_missing_clause( match, debugging=False ):
    
    """String or proper date?  Returns properly formatted SQL that queries for '!missing(...)'"""
    
    if  debugging:
        
        print( match.group( 1 ) )
        print( match.group( 2 ) )
        print( is_proper_date( match.group( 2 ) ) )
    
    if is_proper_date( match.group( 2 ) ):
        
        return "{} IS NOT NULL".format( match.group( 2 ) )
    
    else:
        
        return "length( {} ) > 0 AND {} != '$uNull'".format( match.group( 2 ), match.group( 2 ) )
    
def translate_not_missing( raw_line ):
    
    raw_line = re.sub( r'(!missing\() (PIRL[0-9]{1,}) \)', get_not_missing_clause, raw_line )
        
    return kill_extra_spaces( raw_line )

print( translate_not_missing( "( !missing( PIRL1001 ) AND missing( PIRL1200 ) AND PIRL1300 != 1 )" ) )
# Out:
# ( length( PIRL1001 ) > 0 AND PIRL1001 != '$uNull' AND missing( PIRL1200 ) AND PIRL1300 != 1 )

# %%
def get_missing_clause( match ):
    
    """String or proper date?  Returns properly formatted SQL that queries for 'missing(...)'"""
    
    if  debugging:
        
        print( match.group( 1 ) )
        print( match.group( 2 ) )
        print( is_proper_date( match.group( 2 ) ) )
    
    if is_proper_date( match.group( 2 ) ):
        
        return "{} IS NULL".format( match.group( 2 ) )
    
    else:
        
        return "( length( {} ) = 0 OR {} != '$uNull' )".format( match.group( 2 ), match.group( 2 ) )
    
def translate_missing( raw_line ):
    
    raw_line = re.sub( r'(missing\() (PIRL[0-9]{1,}) \)', get_missing_clause, raw_line )
        
    return kill_extra_spaces( raw_line )

print( translate_missing( "( length( PIRL1001 ) > 0 AND PIRL1001 != '$uNull' AND missing( PIRL1200 ) AND PIRL1300 != 1 )" ) )
# Out:
# ( length( PIRL1001 ) > 0 AND PIRL1001 != '$uNull' AND PIRL1200 IS NULL AND PIRL1300 != 1 )

# %% [markdown]
# ### Translate PIRL to Parquet Names

# %%
def get_column_name( match ):
    
    #return "BINGO!"
    return pirl_dictionary[ match.group( 1 ) ]

def translate_pirl_to_parquet( raw_line ):
    
    return re.sub( r'(PIRL[0-9]{1,})', get_column_name, raw_line )
        
print( translate_pirl_to_parquet( "( length( PIRL1001 ) > 0 AND PIRL1001 != '$uNull' AND missing( PIRL1200 ) AND PIRL1300 != 1 )" ) )
# Out:
# ( length( DateOfFirstBasicCareerServiceStaffAssisted ) > 0 AND DateOfFirstBasicCareerServiceStaffAssisted != '$uNull' AND missing( DateOfFirstIndividualizedCareerService ) AND ReceivedTrainingWIOA != 1 )

# %% [markdown]
# ### Add Scala String Generation Prefix/Suffix

# %%
def add_string_generation( raw_line ):
    
    """Prepends scala's string generation prefix if a ref to a $variable is found"""
    
    # any string gen in effect?
    if "$" in raw_line:        
        
        # insert s""" between variable name and string...
        raw_line = re.sub( r'(val [A-Za-z0-9]{1,} =) (")', r'\1 s"""', raw_line )
        # ...append '""".stripMargin' to end of string
        return re.sub( r'([\"]{1,}$)', r' """', raw_line.strip() )
        
    else:

        return raw_line

add_string_generation( """val foo = "( $partsplit AND ( DateOfProgramEntryWIOA <= to_date( '$qtrend' ) ) AND ( ( DateOfProgramExitWIOA >= to_date( '$begpartdate' ) ) OR DateOfProgramExitWIOA IS NULL ) )" """ )
# Out:
# 'val foo = s"""( $partsplit AND ( DateOfProgramEntryWIOA <= to_date( \'$qtrend\' ) ) AND ( ( DateOfProgramExitWIOA >= to_date( \'$begpartdate\' ) ) OR DateOfProgramExitWIOA IS NULL ) ) """'

# %% [markdown]
# ### Translate "Count if" into SQL SELECT ...

# %%
query_string_id = 0

# %%
def get_unique_var_name( match ):
    
    return 'val query{} = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE{} """'.format( query_string_id, match.group( 2 ) )

def translate_get_if( raw_line ):
    
    return re.sub( r'(count if)(.*)$', get_unique_var_name, raw_line )

translate_get_if( "count if $bcsvc AND $exitdef" )
# Out:
# 'val query1521 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $bcsvc AND $exitdef """'

# %% [markdown]
# ### Wrap All Transformations in One Method

# %%
def apply_transformations( line ):
    
    line = normalize_parenthesis( line )
    line = normalize_plus_signs( line )
    line = normalize_equals( line )
    line = translate_conjuntions( line )
    line = translate_variable_declarations( line )
    line = translate_in_clause( line )
    line = translate_date_vars( line )
    line = translate_date_function( line )
    line = translate_inline_variable_insertions( line )
    line = remove_ref_to_fs( line )
    # Not missing needs to be run before missing, due to weak(er) regex boundaries
    line = translate_not_missing( line )
    line = translate_missing( line )
    line = translate_pirl_to_parquet( line )
    line = add_string_generation( line )
    line = translate_get_if( line )
    
    return line

# %% [markdown]
# ### Test, One Line at a Time

# %%
apply_transformations( """local credden "(`partsplit' & !missing(PIRL900) & PIRL901 >= d(`beginq4date') & PIRL901 <= d(`endq4date') & ((inlist(PIRL1303,2,3,4,6,7,8,9,10) | inlist(PIRL1310,2,3,4,6,7,8,9,10) | inlist(PIRL1315,2,3,4,6,7,8,9,10)) | PIRL1332 == 1 | (PIRL408 == 0 & PIRL1401 == 1)) & PIRL923 == 0)"  """)
# Out:
# 'val credden = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( \'$beginq4date\' ) AND DateOfProgramExitWIOA <= to_date( \'$endq4date\' ) AND ( ( TypeOfTrainingService1WIOA IN ( 2,3,4,6,7,8,9,10 ) OR TypeOfTrainingService2WIOA IN ( 2,3,4,6,7,8,9,10 ) OR TypeOfTrainingService3WIOA IN ( 2,3,4,6,7,8,9,10 ) ) OR ParticipatedInPostsecondaryEducationDuringProgramP = 1 OR ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 0 AND EnrolledInSecondaryEducationProgramAtProgramEntryW = 1 ) ) AND OtherReasonsForExitWIOA = 0 ) """.stripMargin'

# %% [markdown]
# ### Iterate Lines, Apply All Transformations

# %%
debugging = False

counter = 1

for line in stata_list:
    
    words = line.split( " " )
    if words[ 0 ] in translatable:
        
        # update query id
        query_string_id = counter
        line = apply_transformations( line )
        
        print( "")
        print( line )
        
    elif words[ 0 ] not in hideable:
        
        print( "// " + line )
        
    counter += 1
# Out:
# // ********************************************************************************
# // *************************QPR TEST AGGREGATION RULES*****************************
# // ********************************************************************************
# // cd "H:\Data Work\WIPS Test File"
#
# local cdate: display %td-CY-m-D date( c( current_date ),"DMY" )
# // copy "QPR_Template.xlsx" "StataQPROutput`cdate'.xlsx", replace
# // set more off
# // ************FUNDING STREAMS*****************************************************
#
# val Adult = "( AdultWIOA IN ( 1,2,3,4 ) )"
#
# val DW = "( DislocatedWorkerWIOA IN ( 1,2,3,4 ) OR RapidResponseAdditionalAssistance = 1 )"
#
# val WP = "( WagnerPeyserEmploymentServiceWIOA IN ( 1,2 ) )"
#
# val Youth = "( YouthWIOA IN ( 1,2,3,4 ) )"
# // ************PARTICIPANT AND REPORTABLE INDIVIDUAL SPLITS************************
#
# val partsplit = "( AdultWIOA IN ( 1,2,3 ) OR DislocatedWorkerWIOA IN ( 1,2,3 ) OR WagnerPeyserEmploymentServiceWIOA IN ( 1 ) OR YouthWIOA IN ( 1,2,3 ) )"
#
# val risplit = "( AdultWIOA IN ( 4 ) OR DislocatedWorkerWIOA IN ( 4 ) OR WagnerPeyserEmploymentServiceWIOA IN ( 2 ) OR YouthWIOA IN ( 4 ) )"
# // ********Reporting Periods for Quarter Ending 12/31/17  ROLLING 4 QTRS************
# // **Current Period**
#
# val begpartdate = "2017-10-01"
#
# val qtrend = "2018-09-30"
#
# val begexitdate = "2017-07-01"
#
# val endexitdate = "2018-06-30"
#
# val beginq2date = "2016-10-01"
#
# val endq2date = "2017-09-30"
#
# val beginq4date = "2016-07-01"
#
# val endq4date = "2016-03-31"
# // **Previous Period**
#
# val prevbegpartdate = "2017-07-01"
#
# val prevqtrend = "2018-06-30"
#
# val prevbegexitdate = "2017-04-01"
#
# val prevendexitdate = "2018-03-31"
#
# val prevbeginq2date = "2016-07-01"
#
# val prevendq2date = "2017-06-30"
#
# val prevbeginq4date = "2016-07-01"
#
# val prevendq4date = "2016-12-31"
# // ***********Participant, Exiter and Reportable Individual Defintitions***********
#
# val partdef = s"""( $partsplit AND ( DateOfProgramEntryWIOA <= to_date( '$qtrend' ) ) AND ( ( DateOfProgramExitWIOA >= to_date( '$begpartdate' ) ) OR DateOfProgramExitWIOA IS NULL ) ) """
#
# val prevpartdef = s"""( $partsplit AND ( DateOfProgramEntryWIOA <= to_date( '$prevqtrend' ) ) AND ( ( DateOfProgramExitWIOA >= to_date( '$prevbegpartdate' ) ) OR DateOfProgramExitWIOA IS NULL ) ) """
#
# val exitdef = s"""( $partsplit AND ( DateOfProgramExitWIOA >= to_date( '$begexitdate' ) AND DateOfProgramExitWIOA <= to_date( '$endexitdate' ) AND DateOfProgramExitWIOA IS NOT NULL ) ) """
#
# val prevexitdef = s"""( $partsplit AND ( DateOfProgramExitWIOA >= to_date( '$prevbegexitdate' ) AND DateOfProgramExitWIOA <= to_date( '$prevendexitdate' ) AND DateOfProgramExitWIOA IS NOT NULL ) ) """
#
# val reptind = s"""( $risplit AND ( MostRecentDateReceivedBasicCareerServicesSelfServi IS NOT NULL AND MostRecentDateReceivedBasicCareerServicesSelfServi >= to_date( '$begpartdate' ) AND MostRecentDateReceivedBasicCareerServicesSelfServi <= to_date( '$qtrend' ) ) OR ( DateOfMostRecentReportableIndividualContact IS NOT NULL AND DateOfMostRecentReportableIndividualContact >= to_date( '$begpartdate' ) AND DateOfMostRecentReportableIndividualContact <= to_date( '$qtrend' ) ) ) """
#
# val prevreptind = s"""( $risplit AND ( MostRecentDateReceivedBasicCareerServicesSelfServi IS NOT NULL AND MostRecentDateReceivedBasicCareerServicesSelfServi >= to_date( '$prevbegpartdate' ) AND MostRecentDateReceivedBasicCareerServicesSelfServi <= to_date( '$prevqtrend' ) ) OR ( DateOfMostRecentReportableIndividualContact IS NOT NULL AND DateOfMostRecentReportableIndividualContact >= to_date( '$prevbegpartdate' ) AND DateOfMostRecentReportableIndividualContact <= to_date( '$prevqtrend' ) ) ) """
# // ****************Youth Participant and Exiter Defintitions***********************
#
# val ythexitdef = s"""( $partsplit AND DateOfProgramExitWIOA >= to_date( '$begexitdate' ) AND DateOfProgramExitWIOA <= to_date( '$endexitdate' ) AND DateOfFirstWIOAYouthService IS NOT NULL ) """
#
# val ythprevexitdef = s"""( $partsplit AND DateOfProgramExitWIOA >= to_date( '$prevbegexitdate' ) AND DateOfProgramExitWIOA <= to_date( '$prevendexitdate' ) AND DateOfFirstWIOAYouthService IS NOT NULL ) """
#
# val ythpartdef = s"""( $partsplit AND DateOfProgramEntryWIOA <= to_date( '$qtrend' ) ) AND ( ( DateOfProgramExitWIOA >= to_date( '$begpartdate' ) ) OR DateOfProgramExitWIOA IS NULL ) """
#
# val ythprevpartdef = s"""( $partsplit AND DateOfProgramEntryWIOA <= to_date( '$prevqtrend' ) ) AND ( ( DateOfProgramExitWIOA >= to_date( '$prevbegpartdate' ) ) OR DateOfProgramExitWIOA IS NULL ) """
# // ******************Services Defintitions*****************************************
#
# val bcsvc = s"""( length( DateOfFirstBasicCareerServiceStaffAssisted ) > 0 AND DateOfFirstBasicCareerServiceStaffAssisted != '$uNull' AND DateOfFirstIndividualizedCareerService IS NULL AND ReceivedTrainingWIOA != 1 ) """
#
# val icsvc = "( DateOfFirstIndividualizedCareerService IS NOT NULL AND ReceivedTrainingWIOA != 1 )"
#
# val tsvc = "( ReceivedTrainingWIOA = 1 )"
#
# val total = s"""( length( DateOfFirstBasicCareerServiceStaffAssisted ) > 0 AND DateOfFirstBasicCareerServiceStaffAssisted != '$uNull' OR DateOfFirstIndividualizedCareerService IS NOT NULL OR ReceivedTrainingWIOA = 1 ) """
# // ******************Youth Services Defintitions***********************************
#
# val notoccsvc = "( DateOfFirstWIOAYouthService IS NOT NULL AND ReceivedTrainingWIOA != 1 )"
#
# val occsvc = "( DateOfFirstWIOAYouthService IS NOT NULL AND ReceivedTrainingWIOA = 1 )"
#
# val ythtotal = "( DateOfFirstWIOAYouthService IS NOT NULL )"
# // *****************Performance Indicator Definitions******************************
#
# val empq2den = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$beginq2date' ) AND DateOfProgramExitWIOA <= to_date( '$endq2date' ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val empq2num = s"""( $empq2den AND EmployedIn2ndQuarterAfterExitQuarterWIOA > 0 AND EmployedIn2ndQuarterAfterExitQuarterWIOA < 9 ) """
#
# val ythq2num = s"""( $empq2den AND ( ( EmployedIn2ndQuarterAfterExitQuarterWIOA > 0 AND EmployedIn2ndQuarterAfterExitQuarterWIOA < 9 ) OR ( Youth2ndQuarterPlacementTitleIWIOA > 0 AND length( Youth2ndQuarterPlacementTitleIWIOA ) > 0 AND Youth2ndQuarterPlacementTitleIWIOA != '$uNull' ) ) ) """
#
# val empq4den = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$beginq4date' ) AND DateOfProgramExitWIOA <= to_date( '$endq4date' ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val empq4num = s"""( $empq4den AND EmployedIn4thQuarterAfterExitQuarterWIOA > 0 AND EmployedIn4thQuarterAfterExitQuarterWIOA < 9 ) """
#
# val ythq4num = s"""( $empq4den AND ( ( EmployedIn4thQuarterAfterExitQuarterWIOA > 0 AND EmployedIn4thQuarterAfterExitQuarterWIOA < 9 ) OR ( Youth4thQuarterPlacementTitleIWIOA > 0 AND length( Youth4thQuarterPlacementTitleIWIOA ) > 0 AND Youth4thQuarterPlacementTitleIWIOA != '$uNull' ) ) ) """
#
# val meq2 = s"""( $partsplit AND Wages2NdQuarterAfterExitQuarterWIOA > 0 AND Wages2NdQuarterAfterExitQuarterWIOA < 999999.99 AND length( Wages2NdQuarterAfterExitQuarterWIOA ) > 0 AND Wages2NdQuarterAfterExitQuarterWIOA != '$uNull' AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$beginq2date' ) AND DateOfProgramExitWIOA <= to_date( '$endq2date' ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val credden = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$beginq4date' ) AND DateOfProgramExitWIOA <= to_date( '$endq4date' ) AND ( ( TypeOfTrainingService1WIOA IN ( 2,3,4,6,7,8,9,10 ) OR TypeOfTrainingService2WIOA IN ( 2,3,4,6,7,8,9,10 ) OR TypeOfTrainingService3WIOA IN ( 2,3,4,6,7,8,9,10 ) ) OR ParticipatedInPostsecondaryEducationDuringProgramP = 1 OR ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 0 AND EnrolledInSecondaryEducationProgramAtProgramEntryW = 1 ) ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val crednum = s"""( $credden AND ( ( ( DateAttainedRecognizedCredentialWIOA IS NOT NULL AND ( DateAttainedRecognizedCredentialWIOA - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredentialWIOA IN ( 2,3,4,5,6,7 ) ) OR ( DateAttainedRecognizedCredential2 IS NOT NULL AND ( DateAttainedRecognizedCredential2 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential2 IN ( 2,3,4,5,6,7 ) ) OR ( DateAttainedRecognizedCredential3 IS NOT NULL AND ( DateAttainedRecognizedCredential3 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential3 IN ( 2,3,4,5,6,7 ) ) ) OR ( ( ( DateAttainedRecognizedCredentialWIOA IS NOT NULL AND ( DateAttainedRecognizedCredentialWIOA - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredentialWIOA IN ( 1 ) ) OR ( DateAttainedRecognizedCredential2 IS NOT NULL AND ( DateAttainedRecognizedCredential2 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential2 IN ( 1 ) ) OR ( DateAttainedRecognizedCredential3 IS NOT NULL AND ( DateAttainedRecognizedCredential3 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential3 IN ( 1 ) ) ) AND ( ( DateEnrolledInPostExitEducationOrTrainingProgramLe IS NOT NULL AND ( DateEnrolledInPostExitEducationOrTrainingProgramLe - DateOfProgramExitWIOA <= 365 ) ) OR ( EmployedIn1StQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) OR ( EmployedIn2ndQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) OR ( EmployedIn3rdQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) OR ( EmployedIn4thQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) ) ) ) ) """
#
# val msgden = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramEntryWIOA <= to_date( '$qtrend' ) AND ( DateOfProgramExitWIOA IS NULL OR ( DateOfProgramExitWIOA >= to_date( '$begpartdate' ) AND DateOfProgramExitWIOA <= to_date( '$qtrend' ) ) ) AND DateEnrolledDuringProgramParticipationInAnEducatio IS NOT NULL AND ( DateCompletedDuringProgramParticipationAnEducation IS NULL OR ( DateCompletedDuringProgramParticipationAnEducation >= to_date( '$begpartdate' ) AND DateCompletedDuringProgramParticipationAnEducation <= to_date( '$qtrend' ) ) ) AND ( OtherReasonsForExitWIOA IN ( 0,7,. ) ) ) """
#
# val msgnum = s"""( $msgden AND ( ( DateOfMostRecentMeasurableSkillGainsEducationalFun >= to_date( '$begpartdate' ) AND DateOfMostRecentMeasurableSkillGainsEducationalFun <= to_date( '$qtrend' ) ) OR ( ( DateAttainedRecognizedCredentialWIOA >= to_date( '$begpartdate' ) AND DateAttainedRecognizedCredentialWIOA <= to_date( '$qtrend' ) ) AND TypeOfRecognizedCredentialWIOA = 1 ) OR ( ( DateAttainedRecognizedCredential2 >= to_date( '$begpartdate' ) AND DateAttainedRecognizedCredential2 <= to_date( '$qtrend' ) ) AND TypeOfRecognizedCredential2 = 1 ) OR ( ( DateAttainedRecognizedCredential3 >= to_date( '$begpartdate' ) AND DateAttainedRecognizedCredential3 <= to_date( '$qtrend' ) ) AND TypeOfRecognizedCredential3 = 1 ) OR ( DateOfMostRecentMeasurableSkillGainsPostsecondaryT >= to_date( '$begpartdate' ) AND DateOfMostRecentMeasurableSkillGainsPostsecondaryT <= to_date( '$qtrend' ) ) OR ( DateOfMostRecentMeasurableSkillGainsSecondaryTrans >= to_date( '$begpartdate' ) AND DateOfMostRecentMeasurableSkillGainsSecondaryTrans <= to_date( '$qtrend' ) ) OR ( DateOfMostRecentMeasurableSkillGainsTrainingMilest >= to_date( '$begpartdate' ) AND DateOfMostRecentMeasurableSkillGainsTrainingMilest <= to_date( '$qtrend' ) ) OR ( DateOfMostRecentMeasurableSkillGainsSkillsProgress >= to_date( '$begpartdate' ) AND DateOfMostRecentMeasurableSkillGainsSkillsProgress <= to_date( '$qtrend' ) ) ) ) """
# // **************Previous Period Performance Indicator Definitions*****************
#
# val prevempq2den = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$prevbeginq2date' ) AND DateOfProgramExitWIOA <= to_date( '$prevendq2date' ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val prevempq2num = s"""( $empq2den AND EmployedIn2ndQuarterAfterExitQuarterWIOA > 0 AND EmployedIn2ndQuarterAfterExitQuarterWIOA < 9 ) """
#
# val prevythq2num = s"""( $empq2den AND ( ( EmployedIn2ndQuarterAfterExitQuarterWIOA > 0 AND EmployedIn2ndQuarterAfterExitQuarterWIOA < 9 ) OR ( Youth2ndQuarterPlacementTitleIWIOA > 0 AND length( Youth2ndQuarterPlacementTitleIWIOA ) > 0 AND Youth2ndQuarterPlacementTitleIWIOA != '$uNull' ) ) ) """
#
# val prevempq4den = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$prevbeginq4date' ) AND DateOfProgramExitWIOA <= to_date( '$prevendq4date' ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val prevempq4num = s"""( $empq4den AND EmployedIn4thQuarterAfterExitQuarterWIOA > 0 AND EmployedIn4thQuarterAfterExitQuarterWIOA < 9 ) """
#
# val prevythq4num = s"""( $empq4den AND ( ( EmployedIn4thQuarterAfterExitQuarterWIOA > 0 AND EmployedIn4thQuarterAfterExitQuarterWIOA < 9 ) OR ( Youth4thQuarterPlacementTitleIWIOA > 0 AND length( Youth4thQuarterPlacementTitleIWIOA ) > 0 AND Youth4thQuarterPlacementTitleIWIOA != '$uNull' ) ) ) """
#
# val prevmeq2 = s"""( $partsplit AND Wages2NdQuarterAfterExitQuarterWIOA > 0 AND Wages2NdQuarterAfterExitQuarterWIOA < 999999.99 AND length( Wages2NdQuarterAfterExitQuarterWIOA ) > 0 AND Wages2NdQuarterAfterExitQuarterWIOA != '$uNull' AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$prevbeginq2date' ) AND DateOfProgramExitWIOA <= to_date( '$prevendq2date' ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val prevcredden = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramExitWIOA >= to_date( '$prevbeginq4date' ) AND DateOfProgramExitWIOA <= to_date( '$prevendq4date' ) AND ( ( TypeOfTrainingService1WIOA IN ( 2,3,4,6,7,8,9,10 ) OR TypeOfTrainingService2WIOA IN ( 2,3,4,6,7,8,9,10 ) OR TypeOfTrainingService3WIOA IN ( 2,3,4,6,7,8,9,10 ) ) OR ParticipatedInPostsecondaryEducationDuringProgramP = 1 OR ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 0 AND EnrolledInSecondaryEducationProgramAtProgramEntryW = 1 ) ) AND OtherReasonsForExitWIOA = 0 ) """
#
# val prevcrednum = s"""( $credden AND ( ( ( DateAttainedRecognizedCredentialWIOA IS NOT NULL AND ( DateAttainedRecognizedCredentialWIOA - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredentialWIOA IN ( 2,3,4,5,6,7 ) ) OR ( DateAttainedRecognizedCredential2 IS NOT NULL AND ( DateAttainedRecognizedCredential2 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential2 IN ( 2,3,4,5,6,7 ) ) OR ( DateAttainedRecognizedCredential3 IS NOT NULL AND ( DateAttainedRecognizedCredential3 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential3 IN ( 2,3,4,5,6,7 ) ) ) OR ( ( ( DateAttainedRecognizedCredentialWIOA IS NOT NULL AND ( DateAttainedRecognizedCredentialWIOA - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredentialWIOA IN ( 1 ) ) OR ( DateAttainedRecognizedCredential2 IS NOT NULL AND ( DateAttainedRecognizedCredential2 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential2 IN ( 1 ) ) OR ( DateAttainedRecognizedCredential3 IS NOT NULL AND ( DateAttainedRecognizedCredential3 - DateOfProgramExitWIOA <= 365 ) AND TypeOfRecognizedCredential3 IN ( 1 ) ) ) AND ( ( DateEnrolledInPostExitEducationOrTrainingProgramLe IS NOT NULL AND ( DateEnrolledInPostExitEducationOrTrainingProgramLe - DateOfProgramExitWIOA <= 365 ) ) OR ( EmployedIn1StQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) OR ( EmployedIn2ndQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) OR ( EmployedIn3rdQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) OR ( EmployedIn4thQuarterAfterExitQuarterWIOA IN ( 1,2,3 ) ) ) ) ) ) """
#
# val prevmsgden = s"""( $partsplit AND DateOfProgramEntryWIOA IS NOT NULL AND DateOfProgramEntryWIOA <= to_date( '$prevqtrend' ) AND ( DateOfProgramExitWIOA IS NULL OR ( DateOfProgramExitWIOA >= to_date( '$prevbegpartdate' ) AND DateOfProgramExitWIOA <= to_date( '$prevqtrend' ) ) ) AND DateEnrolledDuringProgramParticipationInAnEducatio IS NOT NULL AND ( DateCompletedDuringProgramParticipationAnEducation IS NULL OR ( DateCompletedDuringProgramParticipationAnEducation >= to_date( '$prevbegpartdate' ) AND DateCompletedDuringProgramParticipationAnEducation <= to_date( '$prevqtrend' ) ) ) AND ( OtherReasonsForExitWIOA IN ( 0,7,. ) ) ) """
#
# val prevmsgnum = s"""( $msgden AND ( ( DateOfMostRecentMeasurableSkillGainsEducationalFun >= to_date( '$prevbegpartdate' ) AND DateOfMostRecentMeasurableSkillGainsEducationalFun <= to_date( '$prevqtrend' ) ) OR ( ( DateAttainedRecognizedCredentialWIOA >= to_date( '$prevbegpartdate' ) AND DateAttainedRecognizedCredentialWIOA <= to_date( '$prevqtrend' ) ) AND TypeOfRecognizedCredentialWIOA = 1 ) OR ( ( DateAttainedRecognizedCredential2 >= to_date( '$prevbegpartdate' ) AND DateAttainedRecognizedCredential2 <= to_date( '$prevqtrend' ) ) AND TypeOfRecognizedCredential2 = 1 ) OR ( ( DateAttainedRecognizedCredential3 >= to_date( '$prevbegpartdate' ) AND DateAttainedRecognizedCredential3 <= to_date( '$prevqtrend' ) ) AND TypeOfRecognizedCredential3 = 1 ) OR ( DateOfMostRecentMeasurableSkillGainsPostsecondaryT >= to_date( '$prevbegpartdate' ) AND DateOfMostRecentMeasurableSkillGainsPostsecondaryT <= to_date( '$prevqtrend' ) ) OR ( DateOfMostRecentMeasurableSkillGainsSecondaryTrans >= to_date( '$prevbegpartdate' ) AND DateOfMostRecentMeasurableSkillGainsSecondaryTrans <= to_date( '$prevqtrend' ) ) OR ( DateOfMostRecentMeasurableSkillGainsTrainingMilest >= to_date( '$prevbegpartdate' ) AND DateOfMostRecentMeasurableSkillGainsTrainingMilest <= to_date( '$prevqtrend' ) ) OR ( DateOfMostRecentMeasurableSkillGainsSkillsProgress >= to_date( '$prevbegpartdate' ) AND DateOfMostRecentMeasurableSkillGainsSkillsProgress <= to_date( '$prevqtrend' ) ) ) ) """
# // ********************************************************************************
# //
# // **Set up Age calcs
# // capture noisily drop age
# // gen age = year(PIRL900) - year(PIRL200)
#
# replace age = age - 1 if ( month( DateOfProgramEntryWIOA ) < month( DateOfBirthWIOA ) ) OR ( month( DateOfProgramEntryWIOA ) = month( DateOfBirthWIOA ) AND day( DateOfProgramEntryWIOA ) < day( DateOfBirthWIOA ) )
# // **
# //
# // *FS STORAGE: "(inlist(PIRL903,1,2,3,4))" "(inlist(PIRL904,1,2,3,4) | PIRL909 == 1)" "(inlist(PIRL918,1,2))" "(inlist(PIRL905,1,2,3,4))"
# // foreach FS in "(inlist(PIRL903,1,2,3,4))" "(inlist(PIRL904,1,2,3,4) | PIRL909 == 1)" "(inlist(PIRL918,1,2))" "(inlist(PIRL905,1,2,3,4))" {
# //
# // **Name the excel sheet
# // if "`FS'" == "`Adult'" {
# // macro drop report
#
# val report = "WIOA_Adult"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // if "`FS'" == "`DW'" {
# // macro drop report
#
# val report = "WIOA_DW"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // if "`FS'" == "`WP'" {
# // macro drop report
#
# val report = "Wagner-Peyser"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // if "`FS'" == "`Youth'" {
# // macro drop report
#
# val report = "WIOA_Youth"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // **Title the report by funding stream
# //
# // //////////////**********"Adult" QPR Specs********///////////////////////////////
# //
# // if "`FS'" != "`Youth'" {
# //
# // ***Section A - Summary Information**********************************************
# //
# // *Only Participants included in these counts*
# //
# // *A.1 Total Exiters*
# // **Total Exiters -- Basic Career Services**
#
# val query135 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $bcsvc AND $exitdef """
# //
# // **Total Exiters -- Individualized Career Services**
#
# val query139 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $icsvc AND $exitdef """
# //
# // **Total Exiters -- Training Services**
#
# val query143 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $tsvc AND $exitdef """
# //
# // **Total Exiters -- Total Current Period**
#
# val query147 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $total AND $exitdef """
# //
# // **Total Exiters -- Total Previous Period**
#
# val query151 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $total AND $prevexitdef """
# //
# // *A.2 Total Participants*
# //
# // **Total Participants Served -- Basic Career Services**
#
# val query157 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $bcsvc AND $partdef """
# //
# // *Total Participants Served -- Individualized Career Services**
#
# val query161 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $icsvc AND $partdef """
# //
# // **Total Participants Served -- Training Services**
#
# val query165 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $tsvc AND $partdef """
# //
# // **Total Participants Served -- Total Current Period**
#
# val query169 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $total AND $partdef """
# //
# // **Total Participants Served -- Total Previous Period**
#
# val query173 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $total AND $prevpartdef """
# //
# //
# // *Only Reportable Individuals included in these counts*
# //
# // *A.3 Total Reportable Individuals*
# //
# // **Total Reportable Individuals -- Total Current Period**
#
# val query182 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $reptind """
# //
# // **Total Reportable Individuals -- Total Previous Period**
#
# val query186 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $prevreptind """
# //
# //
# // *Only Participants included in these counts*
# //
# // ***Section B - Participant Summary and Service Information**********************
# //
# // **********************Basic Career Services*************************************
# // *1a. Male*
#
# val query196 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 1 AND $bcsvc AND $partdef """
# // *1b. Female
#
# val query199 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 2 AND $bcsvc AND $partdef """
# // *2a. Hispanic/Latino
#
# val query202 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EthnicityHispanicLatinoWIOA = 1 AND $bcsvc AND $partdef """
# // *2b. American Indian or Alaskan Native
#
# val query205 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AmericanIndianAlaskaNativeWIOA = 1 AND $bcsvc AND $partdef """
# // *2c. Asian
#
# val query208 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AsianWIOA = 1 AND $bcsvc AND $partdef """
# // *2d. Black or African American
#
# val query211 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE BlackAfricanAmericanWIOA = 1 AND $bcsvc AND $partdef """
# // *2e. Native Hawaiian or Other Pacific Islander
#
# val query214 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE NativeHawaiianOtherPacificIslanderWIOA = 1 AND $bcsvc AND $partdef """
# // *2f. White
#
# val query217 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE WhiteWIOA = 1 AND $bcsvc AND $partdef """
# // *2g. More Than One Race
#
# val query220 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 2 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 3 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 4 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 5 ) ) AND $bcsvc AND $partdef """
# // *3a. Eligible Veterans
#
# val query223 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EligibleVeteranStatus > 1 AND length( EligibleVeteranStatus ) > 0 AND EligibleVeteranStatus != '$uNull' ) AND $bcsvc AND $partdef """
# // *3b. Individuals with a Disability
#
# val query226 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE IndividualWithADisabilityWIOA = 1 AND $bcsvc AND $partdef """
# // *3c. Incumbent Workers
#
# val query229 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( RecipientOfIncumbentWorkerTraining > 0 AND length( RecipientOfIncumbentWorkerTraining ) > 0 AND RecipientOfIncumbentWorkerTraining != '$uNull' ) AND $bcsvc AND $partdef """
# // *3d. Unemployed Individuals
#
# val query232 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EmploymentStatusAtProgramEntryWIOA = 0 OR EmploymentStatusAtProgramEntryWIOA = 2 OR EmploymentStatusAtProgramEntryWIOA = 3 ) AND $bcsvc AND $partdef """
# // *4a. Secondary School Graduate or Equivalent
#
# val query235 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 1 OR HighestEducationalLevelCompletedAtProgramEntryWIOA = 2 ) AND $bcsvc AND $partdef """
# // *4b. Completed 1 or more years of Postsecondary Education
#
# val query238 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 4 AND $bcsvc AND $partdef """
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
#
# val query241 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 5 AND $bcsvc AND $partdef """
# // *4d. Associate's Degree
#
# val query244 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 6 AND $bcsvc AND $partdef """
# // *4e. Bachelor's Degree or Equivalent
#
# val query247 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 7 AND $bcsvc AND $partdef """
# // *4f. Advanced Degree Beyond Bachelor's Degree
#
# val query250 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 8 AND $bcsvc AND $partdef """
# //
# // ***********************Individualized Career Services***************************
# // *1a. Male*
#
# val query255 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 1 AND $icsvc AND $partdef """
# // *1b. Female
#
# val query258 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 2 AND $icsvc AND $partdef """
# // *2a. Hispanic/Latino
#
# val query261 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EthnicityHispanicLatinoWIOA = 1 AND $icsvc AND $partdef """
# // *2b. American Indian or Alaskan Native
#
# val query264 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AmericanIndianAlaskaNativeWIOA = 1 AND $icsvc AND $partdef """
# // *2c. Asian
#
# val query267 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AsianWIOA = 1 AND $icsvc AND $partdef """
# // *2d. Black or African American
#
# val query270 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE BlackAfricanAmericanWIOA = 1 AND $icsvc AND $partdef """
# // *2e. Native Hawaiian or Other Pacific Islander
#
# val query273 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE NativeHawaiianOtherPacificIslanderWIOA = 1 AND $icsvc AND $partdef """
# // *2f. White
#
# val query276 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE WhiteWIOA = 1 AND $icsvc AND $partdef """
# // *2g. More Than One Race
#
# val query279 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 2 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 3 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 4 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 5 ) ) AND $icsvc AND $partdef """
# // *3a. Eligible Veterans
#
# val query282 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EligibleVeteranStatus > 1 AND length( EligibleVeteranStatus ) > 0 AND EligibleVeteranStatus != '$uNull' ) AND $icsvc AND $partdef """
# // *3b. Individuals with a Disability
#
# val query285 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE IndividualWithADisabilityWIOA = 1 AND $icsvc AND $partdef """
# // *3c. Incumbent Workers
#
# val query288 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( RecipientOfIncumbentWorkerTraining > 0 AND length( RecipientOfIncumbentWorkerTraining ) > 0 AND RecipientOfIncumbentWorkerTraining != '$uNull' ) AND $icsvc AND $partdef """
# // *3d. Unemployed Individuals
#
# val query291 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EmploymentStatusAtProgramEntryWIOA = 0 OR EmploymentStatusAtProgramEntryWIOA = 2 OR EmploymentStatusAtProgramEntryWIOA = 3 ) AND $icsvc AND $partdef """
# // *4a. Secondary School Graduate or Equivalent
#
# val query294 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 1 OR HighestEducationalLevelCompletedAtProgramEntryWIOA = 2 ) AND $icsvc AND $partdef """
# // *4b. Completed 1 or more years of Postsecondary Education
#
# val query297 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 4 AND $icsvc AND $partdef """
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
#
# val query300 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 5 AND $icsvc AND $partdef """
# // *4d. Associate's Degree
#
# val query303 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 6 AND $icsvc AND $partdef """
# // *4e. Bachelor's Degree or Equivalent
#
# val query306 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 7 AND $icsvc AND $partdef """
# // *4f. Advanced Degree Beyond Bachelor's Degree
#
# val query309 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 8 AND $icsvc AND $partdef """
# //
# // *******************************Training Services********************************
# // *1a. Male*
#
# val query314 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 1 AND $tsvc AND $partdef """
# // *1b. Female
#
# val query317 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 2 AND $tsvc AND $partdef """
# // *2a. Hispanic/Latino
#
# val query320 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EthnicityHispanicLatinoWIOA = 1 AND $tsvc AND $partdef """
# // *2b. American Indian or Alaskan Native
#
# val query323 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AmericanIndianAlaskaNativeWIOA = 1 AND $tsvc AND $partdef """
# // *2c. Asian
#
# val query326 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AsianWIOA = 1 AND $tsvc AND $partdef """
# // *2d. Black or African American
#
# val query329 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE BlackAfricanAmericanWIOA = 1 AND $tsvc AND $partdef """
# // *2e. Native Hawaiian or Other Pacific Islander
#
# val query332 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE NativeHawaiianOtherPacificIslanderWIOA = 1 AND $tsvc AND $partdef """
# // *2f. White
#
# val query335 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE WhiteWIOA = 1 AND $tsvc AND $partdef """
# // *2g. More Than One Race
#
# val query338 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 2 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 3 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 4 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 5 ) ) AND $tsvc AND $partdef """
# // *3a. Eligible Veterans
#
# val query341 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EligibleVeteranStatus > 1 AND length( EligibleVeteranStatus ) > 0 AND EligibleVeteranStatus != '$uNull' ) AND $tsvc AND $partdef """
# // *3b. Individuals with a Disability
#
# val query344 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE IndividualWithADisabilityWIOA = 1 AND $tsvc AND $partdef """
# // *3c. Incumbent Workers
#
# val query347 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( RecipientOfIncumbentWorkerTraining > 0 AND length( RecipientOfIncumbentWorkerTraining ) > 0 AND RecipientOfIncumbentWorkerTraining != '$uNull' ) AND $tsvc AND $partdef """
# // *3d. Unemployed Individuals
#
# val query350 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EmploymentStatusAtProgramEntryWIOA = 0 OR EmploymentStatusAtProgramEntryWIOA = 2 OR EmploymentStatusAtProgramEntryWIOA = 3 ) AND $tsvc AND $partdef """
# // *4a. Secondary School Graduate or Equivalent
#
# val query353 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 1 OR HighestEducationalLevelCompletedAtProgramEntryWIOA = 2 ) AND $tsvc AND $partdef """
# // *4b. Completed 1 or more years of Postsecondary Education
#
# val query356 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 4 AND $tsvc AND $partdef """
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
#
# val query359 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 5 AND $tsvc AND $partdef """
# // *4d. Associate's Degree
#
# val query362 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 6 AND $tsvc AND $partdef """
# // *4e. Bachelor's Degree or Equivalent
#
# val query365 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 7 AND $tsvc AND $partdef """
# // *4f. Advanced Degree Beyond Bachelor's Degree
#
# val query368 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 8 AND $tsvc AND $partdef """
# //
# // ********************Total Current Period****************************************
# // *1a. Male*
#
# val query373 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 1 AND $total AND $partdef """
# // *1b. Female
#
# val query376 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 2 AND $total AND $partdef """
# // *2a. Hispanic/Latino
#
# val query379 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EthnicityHispanicLatinoWIOA = 1 AND $total AND $partdef """
# // *2b. American Indian or Alaskan Native
#
# val query382 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AmericanIndianAlaskaNativeWIOA = 1 AND $total AND $partdef """
# // *2c. Asian
#
# val query385 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AsianWIOA = 1 AND $total AND $partdef """
# // *2d. Black or African American
#
# val query388 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE BlackAfricanAmericanWIOA = 1 AND $total AND $partdef """
# // *2e. Native Hawaiian or Other Pacific Islander
#
# val query391 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE NativeHawaiianOtherPacificIslanderWIOA = 1 AND $total AND $partdef """
# // *2f. White
#
# val query394 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE WhiteWIOA = 1 AND $total AND $partdef """
# // *2g. More Than One Race
#
# val query397 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 2 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 3 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 4 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 5 ) ) AND $total AND $partdef """
# // *3a. Eligible Veterans
#
# val query400 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EligibleVeteranStatus > 1 AND length( EligibleVeteranStatus ) > 0 AND EligibleVeteranStatus != '$uNull' ) AND $total AND $partdef """
# // *3b. Individuals with a Disability
#
# val query403 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE IndividualWithADisabilityWIOA = 1 AND $total AND $partdef """
# // *3c. Incumbent Workers
#
# val query406 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( RecipientOfIncumbentWorkerTraining > 0 AND length( RecipientOfIncumbentWorkerTraining ) > 0 AND RecipientOfIncumbentWorkerTraining != '$uNull' ) AND $total AND $partdef """
# // *3d. Unemployed Individuals
#
# val query409 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EmploymentStatusAtProgramEntryWIOA = 0 OR EmploymentStatusAtProgramEntryWIOA = 2 OR EmploymentStatusAtProgramEntryWIOA = 3 ) AND $total AND $partdef """
# // *4a. Secondary School Graduate or Equivalent
#
# val query412 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 1 OR HighestEducationalLevelCompletedAtProgramEntryWIOA = 2 ) AND $total AND $partdef """
# // *4b. Completed 1 or more years of Postsecondary Education
#
# val query415 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 4 AND $total AND $partdef """
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
#
# val query418 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 5 AND $total AND $partdef """
# // *4d. Associate's Degree
#
# val query421 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 6 AND $total AND $partdef """
# // *4e. Bachelor's Degree or Equivalent
#
# val query424 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 7 AND $total AND $partdef """
# // *4f. Advanced Degree Beyond Bachelor's Degree
#
# val query427 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 8 AND $total AND $partdef """
# //
# // **********************Total Previous Period*************************************
# // *1a. Male*
#
# val query432 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 1 AND $total AND $prevpartdef """
# // *1b. Female
#
# val query435 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE Sex = 2 AND $total AND $prevpartdef """
# // *2a. Hispanic/Latino
#
# val query438 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EthnicityHispanicLatinoWIOA = 1 AND $total AND $prevpartdef """
# // *2b. American Indian or Alaskan Native
#
# val query441 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AmericanIndianAlaskaNativeWIOA = 1 AND $total AND $prevpartdef """
# // *2c. Asian
#
# val query444 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE AsianWIOA = 1 AND $total AND $prevpartdef """
# // *2d. Black or African American
#
# val query447 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE BlackAfricanAmericanWIOA = 1 AND $total AND $prevpartdef """
# // *2e. Native Hawaiian or Other Pacific Islander
#
# val query450 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE NativeHawaiianOtherPacificIslanderWIOA = 1 AND $total AND $prevpartdef """
# // *2f. White
#
# val query453 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE WhiteWIOA = 1 AND $total AND $prevpartdef """
# // *2g. More Than One Race
#
# val query456 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 2 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 3 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 4 ) OR ( ( AmericanIndianAlaskaNativeWIOA + AsianWIOA + BlackAfricanAmericanWIOA + NativeHawaiianOtherPacificIslanderWIOA + WhiteWIOA ) = 5 ) ) AND $total AND $prevpartdef """
# // *3a. Eligible Veterans
#
# val query459 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EligibleVeteranStatus > 1 AND length( EligibleVeteranStatus ) > 0 AND EligibleVeteranStatus != '$uNull' ) AND $total AND $prevpartdef """
# // *3b. Individuals with a Disability
#
# val query462 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE IndividualWithADisabilityWIOA = 1 AND $total AND $prevpartdef """
# // *3c. Incumbent Workers
#
# val query465 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( RecipientOfIncumbentWorkerTraining > 0 AND length( RecipientOfIncumbentWorkerTraining ) > 0 AND RecipientOfIncumbentWorkerTraining != '$uNull' ) AND $total AND $prevpartdef """
# // *3d. Unemployed Individuals
#
# val query468 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( EmploymentStatusAtProgramEntryWIOA = 0 OR EmploymentStatusAtProgramEntryWIOA = 2 OR EmploymentStatusAtProgramEntryWIOA = 3 ) AND $total AND $prevpartdef """
# // *4a. Secondary School Graduate or Equivalent
#
# val query471 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( HighestEducationalLevelCompletedAtProgramEntryWIOA = 1 OR HighestEducationalLevelCompletedAtProgramEntryWIOA = 2 ) AND $total AND $prevpartdef """
# // *4b. Completed 1 or more years of Postsecondary Education
#
# val query474 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 4 AND $total AND $prevpartdef """
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
#
# val query477 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 5 AND $total AND $prevpartdef """
# // *4d. Associate's Degree
#
# val query480 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 6 AND $total AND $prevpartdef """
# // *4e. Bachelor's Degree or Equivalent
#
# val query483 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 7 AND $total AND $prevpartdef """
# // *4f. Advanced Degree Beyond Bachelor's Degree
#
# val query486 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HighestEducationalLevelCompletedAtProgramEntryWIOA = 8 AND $total AND $prevpartdef """
# //
# // ***Section C - Employment Barrier***********************************************
# //
# // **********************Basic Career Services*************************************
# // *1. Displaced homemakers
#
# val query493 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE DisplacedHomemakerAtProgramEntryWIOA = 1 AND $bcsvc AND $partdef """
# // *2. Low-income individuals
#
# val query496 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE LowIncomeStatusAtProgramEntryWIOA = 1 AND $bcsvc AND $partdef """
# // *3. Older individuals
#
# val query499 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( age >= 55 ) AND $bcsvc AND $partdef """
# // *4. Ex-offenders
#
# val query502 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ExOffenderStatusAtProgramEntryWIOA = 1 AND $bcsvc AND $partdef """
# // *5. Homeless individuals or runaway youth
#
# val query505 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HomelessParticipantHomelessChildrenAndYouthsOrRuna = 1 AND $bcsvc AND $partdef """
# // *6. Current or former foster care youth
#
# val query508 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE FosterCareYouthStatusAtProgramEntryWIOA = 1 AND age >= 14 AND age <=24 AND $bcsvc AND $partdef """
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
#
# val query511 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( CulturalBarriersAtProgramEntryWIOA = 1 OR EnglishLanguageLearnerAtProgramEntryWIOA = 1 OR BasicSkillsDeficientLowLevelsOfLiteracyAtProgramEn = 1 ) AND $bcsvc AND $partdef """
# // *8. Eligible migrant and seasonal farmworkers
#
# val query514 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( MigrantAndSeasonalFarmworkerStatusAtNationalFarmwo > 0 AND length( MigrantAndSeasonalFarmworkerStatusAtNationalFarmwo ) > 0 AND MigrantAndSeasonalFarmworkerStatusAtNationalFarmwo != '$uNull' ) AND $bcsvc AND $partdef """
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
#
# val query517 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ExhaustingTanfWithin2YearsPartATitleIvOfTheSocialS = 1 AND $bcsvc AND $partdef """
# // *10. Single parents (Including single pregnant women)
#
# val query520 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE SingleParentAtProgramEntryWIOA = 1 AND $bcsvc AND $partdef """
# // *11. Long-term unemployed (27 or more consecutive weeks)
#
# val query523 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE LongTermUnemployedAtProgramEntryWIOA = 1 AND $bcsvc AND $partdef """
# //
# // **********************Individualized Career Services****************************
# // *1. Displaced homemakers
#
# val query528 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE DisplacedHomemakerAtProgramEntryWIOA = 1 AND $icsvc AND $partdef """
# // *2. Low-income individuals
#
# ...
# // **************************************************Youth Total Previous Period***
# //
# // *1. Displaced homemakers
#
# val query1303 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE DisplacedHomemakerAtProgramEntryWIOA = 1 AND $ythtotal AND $ythprevpartdef """
# // *2. Low-income individuals
#
# val query1306 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE LowIncomeStatusAtProgramEntryWIOA = 1 AND $ythtotal AND $ythprevpartdef """
# // *3. Older individuals
#
# val query1309 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( age >= 55 ) AND $ythtotal AND $ythprevpartdef """
# // *4. Ex-offenders
#
# val query1312 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ExOffenderStatusAtProgramEntryWIOA = 1 AND $ythtotal AND $ythprevpartdef """
# // *5. Homeless individuals or runaway youth
#
# val query1315 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE HomelessParticipantHomelessChildrenAndYouthsOrRuna = 1 AND $ythtotal AND $ythprevpartdef """
# // *6. Current or former foster care youth
#
# val query1318 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE FosterCareYouthStatusAtProgramEntryWIOA = 1 AND $ythtotal AND $ythprevpartdef """
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
#
# val query1321 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( CulturalBarriersAtProgramEntryWIOA = 1 OR EnglishLanguageLearnerAtProgramEntryWIOA = 1 OR BasicSkillsDeficientLowLevelsOfLiteracyAtProgramEn = 1 ) AND $ythtotal AND $ythprevpartdef """
# // *8. Eligible migrant and seasonal farmworkers
#
# val query1324 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ( MigrantAndSeasonalFarmworkerStatusAtNationalFarmwo > 0 AND length( MigrantAndSeasonalFarmworkerStatusAtNationalFarmwo ) > 0 AND MigrantAndSeasonalFarmworkerStatusAtNationalFarmwo != '$uNull' ) AND $ythtotal AND $ythprevpartdef """
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
#
# val query1327 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE ExhaustingTanfWithin2YearsPartATitleIvOfTheSocialS = 1 AND $ythtotal AND $ythprevpartdef """
# // *10. Single parents (Including single pregnant women)
#
# val query1330 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE SingleParentAtProgramEntryWIOA = 1 AND $ythtotal AND $ythprevpartdef """
# // *11. Long-term unemployed (27 or more consecutive weeks)
#
# val query1333 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE LongTermUnemployedAtProgramEntryWIOA = 1 AND $ythtotal AND $ythprevpartdef """
# //
# // ***Section D - Primary Indicators of Performance********************************
# //
# // *************************************D.1 Youth Employment/Placement Rate (Q2)***
# //
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Received Services Other Than Occupational Skills Training**
#
# val query1342 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $ythq2num """
# // scalar NOythq2num = r(N)
#
# val query1344 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $empq2den """
# // scalar NOythq2den = r(N)
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Youth Participants Who Have Received Occupational Skills Training**
#
# val query1349 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $ythq2num """
# // scalar OSythq2num = r(N)
#
# val query1351 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $empq2den """
# // scalar OSythq2den = r(N)
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Youth Total Current Period**
#
# val query1356 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $ythq2num """
# // scalar TCythq2num = r(N)
#
# val query1358 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $empq2den """
# // scalar TCythq2den = r(N)
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Youth Total Previous Period**
#
# val query1363 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevythq2num """
# // scalar TPythq2num = r(N)
#
# val query1365 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevempq2den """
# // scalar TPythq2den = r(N)
# //
# // *************************************D.2 Youth Employment/Placement Rate (Q4)***
# //
# // **Employment, Education, or Training Placement Rate (Q4) -- Received Services Other Than Occupational Skills Training**
#
# val query1372 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $ythq4num """
# // scalar NOythq4num = r(N)
#
# val query1374 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $empq4den """
# // scalar NOythq4den = r(N)
# //
# // **Employment, Education, or Training Placement Rate (Q4) -- Youth Participants Who Have Received Occupational Skills Training**
#
# val query1379 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $ythq4num """
# // scalar OSythq4num = r(N)
#
# val query1381 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $empq4den """
# // scalar OSythq4den = r(N)
# //
# // **Employment, Education, or Training Placement Rate (Q4) -- Youth Total Current Period**
#
# val query1386 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $ythq4num """
# // scalar TCythq4num = r(N)
#
# val query1388 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $empq4den """
# // scalar TCythq4den = r(N)
# // /*
# // **Employment, Education, or Training Placement Rate (Q4) -- Youth Total Previous Period**
#
# val query1393 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevythq4num """
# // scalar TPythq4num = r(N)
#
# val query1395 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevempq4den """
# // scalar TPythq4den = r(N)
# // */
# // **********************************************************D.3 Median Earnings***
# //
# // **Median Earnings -- Received Services Other Than Occupational Skills Training**
# // capture noisily sum PIRL1704 if `FS' & `notoccsvc' & `meq2', detail
# //
# // **Median Earnings -- Youth Participants Who Have Received Occupational Skills Training**"
# // capture noisily sum PIRL1704 if `FS' & `occsvc' & `meq2', detail
# //
# // **Median Earnings -- Youth Total Current Period**
# // capture noisily sum PIRL1704 if `FS' & `ythtotal' & `meq2', detail
# //
# // **Median Earnings -- Youth Total Previous Period**
# // capture noisily sum PIRL1704 if `FS' & `ythtotal' & `prevmeq2', detail
# //
# // **********************************************************D.4 Credential Rate***
# //
# // **Credential Rate -- Received Services Other Than Occupational Skills Training**
#
# val query1420 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $crednum """
# // scalar NOythcrednum = r(N)
#
# val query1422 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $credden """
# // scalar NOythcredden = r(N)
# //
# // **Credential Rate -- Youth Participants Who Have Received Occupational Skills Training**
#
# val query1427 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $crednum """
# // scalar OSythcrednum = r(N)
#
# val query1429 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $credden """
# // scalar OSythcredden = r(N)
# //
# // **Credential Rate -- Youth Total Current Period**
#
# val query1434 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $crednum """
# // scalar TCythcrednum = r(N)
#
# val query1436 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $credden """
# // scalar TCythcredden = r(N)
# // /*
# // **Credential Rate -- Youth Total Previous Period**
#
# val query1441 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevcrednum """
# // scalar TPythcrednum = r(N)
#
# val query1443 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevcredden """
# // scalar TPythcredden = r(N)
# // */
# // ***************************************************D.5 Measurable Skill Gains***
# //
# // **Measurable Skill Gains -- Received Services Other Than Occupational Skills Training**
#
# val query1450 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $msgnum """
# // scalar NOythmsgnum = r(N)
#
# val query1452 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $notoccsvc AND $msgden """
# // scalar NOythmsgden = r(N)
# //
# // **Measurable Skill Gains -- Youth Participants Who Have Received Occupational Skills Training**
#
# val query1457 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $msgnum """
# // scalar OSythmsgnum = r(N)
#
# val query1459 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $occsvc AND $msgden """
# // scalar OSythmsgden = r(N)
# //
# // **Measurable Skill Gains -- Youth Total Current Period**
#
# val query1464 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $msgnum """
# // scalar TCythmsgnum = r(N)
#
# val query1466 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $msgden """
# // scalar TCythmsgden = r(N)
# //
# // **Measurable Skill Gains -- Youth Total Previous Period**
#
# val query1471 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevmsgnum """
# // scalar TPythmsgnum = r(N)
#
# val query1473 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE $ythtotal AND $prevmsgden """
# // scalar TPythmsgden = r(N)
# //
# // ***Section E - Veterans' Priority of Service************************************
# //
# // ***********E.1 Total Covered Entrants Who Reached the End of the Entry Period***
# //
# // **Total Covered Entrants Who Reached the End of the Entry Period -- Total Covered Entrants**
#
# val query1482 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$begpartdate' ) AND CoveredPersonEntryDate <= to_date( '$qtrend' ) ) """
# //
# // ****E.2 Total Covered Entrants Who Received a Service During the Entry Period***
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Total Covered Entrants*
#
# val query1488 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$begpartdate' ) AND CoveredPersonEntryDate <= to_date( '$qtrend' ) ) AND ( ( length( DateOfFirstBasicCareerServiceSelfService ) > 0 AND DateOfFirstBasicCareerServiceSelfService != '$uNull' AND ( DateOfFirstBasicCareerServiceSelfService - CoveredPersonEntryDate ) <= 45 ) OR ( DateOfProgramEntryWIOA IS NOT NULL AND ( DateOfProgramEntryWIOA - CoveredPersonEntryDate ) <= 45 ) ) """
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Percent Served Current Period**
#
# val query1492 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$begpartdate' ) AND CoveredPersonEntryDate <= to_date( '$qtrend' ) ) AND ( ( length( DateOfFirstBasicCareerServiceSelfService ) > 0 AND DateOfFirstBasicCareerServiceSelfService != '$uNull' AND ( DateOfFirstBasicCareerServiceSelfService - CoveredPersonEntryDate ) <= 45 ) OR ( DateOfProgramEntryWIOA IS NOT NULL AND ( DateOfProgramEntryWIOA - CoveredPersonEntryDate ) <= 45 ) ) """
# // scalar VPOS2ythnum = r(N)
#
# val query1494 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$begpartdate' ) AND CoveredPersonEntryDate <= to_date( '$qtrend' ) ) """
# // scalar VPOS2ythden = r(N)
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Percent Served Previous Period**
#
# val query1499 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$prevbegpartdate' ) AND CoveredPersonEntryDate <= to_date( '$prevqtrend' ) ) AND ( ( length( DateOfFirstBasicCareerServiceSelfService ) > 0 AND DateOfFirstBasicCareerServiceSelfService != '$uNull' AND ( DateOfFirstBasicCareerServiceSelfService - CoveredPersonEntryDate ) <= 45 ) OR ( DateOfProgramEntryWIOA IS NOT NULL AND ( DateOfProgramEntryWIOA - CoveredPersonEntryDate ) <= 45 ) ) """
# // scalar VPOS2pythnum = r(N)
#
# val query1501 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$prevbegpartdate' ) AND CoveredPersonEntryDate <= to_date( '$prevqtrend' ) ) """
# // scalar VPOS2pythden = r(N)
# //
# // *E.3 Covered Entrants Who Received a Staff-Assisted Service During the Entry Period***
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Total Covered Entrants**
#
# val query1508 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$begpartdate' ) AND CoveredPersonEntryDate <= to_date( '$qtrend' ) ) AND ( DateOfProgramEntryWIOA IS NOT NULL AND ( DateOfProgramEntryWIOA - CoveredPersonEntryDate ) <= 45 ) """
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Percent Served Current Period**
#
# val query1512 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$begpartdate' ) AND CoveredPersonEntryDate <= to_date( '$qtrend' ) ) AND ( DateOfProgramEntryWIOA IS NOT NULL AND ( DateOfProgramEntryWIOA - CoveredPersonEntryDate ) <= 45 ) """
# // scalar VPOS3ythnum = r(N)
#
# val query1514 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$begpartdate' ) AND CoveredPersonEntryDate <= to_date( '$qtrend' ) ) """
# // scalar VPOS3ythden = r(N)
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Percent Served Previous Period**
#
# val query1519 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$prevbegpartdate' ) AND CoveredPersonEntryDate <= to_date( '$prevqtrend' ) ) AND ( DateOfProgramEntryWIOA IS NOT NULL AND ( DateOfProgramEntryWIOA - CoveredPersonEntryDate ) <= 45 ) """
# // scalar VPOS3pythnum = r(N)
#
# val query1521 = s"""SELECT count( UniqueIndividualIdentifierWIOA ) as count FROM edrvs WHERE EligibleVeteranStatus IN ( 1,2,3 ) AND ( CoveredPersonEntryDate >= to_date( '$prevbegpartdate' ) AND CoveredPersonEntryDate <= to_date( '$prevqtrend' ) ) """
# // scalar VPOS3pythden = r(N)
# //
# // }
# //
# // display _newline
# // display "*********** " "`report'" " Complete **********"
# // display _newline
# // }
# // ********************************************************************************
# // *********************************END OF REPORT**********************************
# // ********************************************************************************

# %%
foo = stata_list[ 0 ]
print( foo )
# Out:
# ********************************************************************************
