# %%
import pandas as pd
import re

# %% [markdown]
# ### Load Stata Source

# %%
stata_file = open( "data/QprExport-2018.06.29.stata", 'r' )
stata_list = [line.strip() for line in stata_file.readlines() ]

# %%
stata_list[ 0 ]
# Out:
# '********************************************************************************'

# %% [markdown]
# ### Load Pirl 'n' Parquet Names

# %%
pirl_to_parquet = pd.read_csv( "data/raw-pirl-to-parquet-names.csv", usecols=[ "PIRL_ElementNumber", "ParquetName" ] )
pirl_to_parquet[ "Pirl" ] = "PIRL" + pirl_to_parquet.PIRL_ElementNumber
pirl_to_parquet.drop( "PIRL_ElementNumber", inplace=True, axis=1 )
    
print( pirl_to_parquet.head() )

# get as dictionary: EZ!
pirl_dictionary = dict( zip( pirl_to_parquet.Pirl, pirl_to_parquet.ParquetName ) )
# Out:
#                       ParquetName     Pirl
# 0                       ObsNumber    PIRL0
# 1  UniqueIndividualIdentifierWIOA  PIRL100
# 2        StateCodeOfResidenceWIOA  PIRL101
# 3           CountyCodeOfResidence  PIRL102
# 4              ZipCodeOfResidence  PIRL103

# %%
pirl_dictionary
# Out:
# {'PIRL0': 'ObsNumber',
#  'PIRL100': 'UniqueIndividualIdentifierWIOA',
#  'PIRL1000': 'DateOfFirstBasicCareerServiceSelfService',
#  'PIRL1001': 'DateOfFirstBasicCareerServiceStaffAssisted',
#  'PIRL1002': 'MostRecentDateReceivedBasicCareerServicesSelfServi',
#  'PIRL1003': 'MostRecentDateReceivedBasicCareerServicesStaffAssi',
#  'PIRL1004': 'DateOfMostRecentCareerServiceWIOA',
#  'PIRL1005': 'MostRecentDateReceivedStaffAssistedServicesDVOPSpe',
#  'PIRL1006': 'DateReferredToDepartmentOfVeteransAffairsVocationa',
#  'PIRL1007': 'DateOfMostRecentReportableIndividualContact',
#  'PIRL101': 'StateCodeOfResidenceWIOA',
#  'PIRL102': 'CountyCodeOfResidence',
#  'PIRL103': 'ZipCodeOfResidence',
#  'PIRL104': 'EconomicLaborMarketAreaAndPhysicalLocationCode',
#  'PIRL105': 'SpecialProjectId1',
#  'PIRL106': 'SpecialProjectId2',
#  'PIRL107': 'SpecialProjectId3',
#  'PIRL108-A': 'ETAAssigned1StLocalWorkforceBoardCode',
#  'PIRL108-B': 'ETAAssigned2NdLocalWorkforceBoardCode',
#  'PIRL108-C': 'ETAAssigned3RdLocalWorkforceBoardCode',
#  'PIRL1100': 'MostRecentDateAccessedSelfServiceInformationOnlyAc',
#  'PIRL1101': 'MostRecentDateAccessedSelfServiceWorkforceInformat',
#  'PIRL1102': 'MostRecentDateReceivedStaffAssistedCareerGuidanceS',
#  'PIRL1103': 'MostRecentDateReceivedStaffAssistedWorkforceInform',
#  'PIRL1104': 'MostRecentDateReceivedStaffAssistedJobSearchActivi',
#  'PIRL1105': 'MostRecentDateReferredToEmployment',
#  'PIRL1106': 'MostRecentDateReferredToFederalTraining',
#  'PIRL1107': 'MostRecentDatePlacedInFederalTraining',
#  'PIRL1108': 'MostRecentDateReferredToFederalJob',
#  'PIRL1109': 'MostRecentDateReferredToFederalContractorJob',
#  'PIRL1110': 'MostRecentDateEnteredIntoFederalJob',
#  'PIRL1111': 'MostRecentDateEnteredIntoFederalContractorJob',
#  'PIRL1112': 'MostRecentDateReceivedUnemploymentInsuranceUIClaim',
#  'PIRL1113': 'MostRecentDateReferredToOtherFederalStateAssistanc',
#  'PIRL1114': 'ReferredToJobsForVeteransStateGrantsJVSGServices',
#  'PIRL1115': 'ReferredToDepartmentOfVeteransAffairsVAServices',
#  'PIRL1116': 'MostRecentDateReceivedStaffAssistedBasicCareerServ',
#  'PIRL1200': 'DateOfFirstIndividualizedCareerService',
#  'PIRL1201': 'MostRecentDateReceivedIndividualizedCareerService',
#  'PIRL1202': 'DateIndividualEmploymentPlanCreated',
#  'PIRL1203': 'MostRecentDateReceivedInternshipOrWorkExperienceOp',
#  'PIRL1205': 'TypeOfWorkExperience',
#  'PIRL1206': 'DateReceivedFinancialLiteracyServices',
#  'PIRL1207': 'DateReceivedEnglishAsSecondLanguageServices',
#  'PIRL1210': 'ReceivedPreVocationalActivities',
#  'PIRL1211': 'TransitionalJobs',
#  'PIRL1213': 'MostRecentDateReceivedIndividualizedCareerServiceD',
#  'PIRL1214': 'MostRecentDateReceivedJobSearchActivitiesDVOP',
#  'PIRL1215': 'MostRecentDateReferredToEmploymentDVOP',
#  'PIRL1216': 'MostRecentDateReferredToFederalTrainingDVOP',
#  'PIRL1217': 'MostRecentDateReferredToFederalJobDVOP',
#  'PIRL1218': 'MostRecentDateReferredToFederalContractorJobDVOP',
#  'PIRL1219': 'MostRecentDateReceivedOtherStaffAssistedBasicCaree',
#  'PIRL1220': 'MostRecentDateReceivedCareerGuidanceServicesDVOP',
#  'PIRL1221': 'MostRecentDateEnteredFederalJobDVOP',
#  'PIRL1222': 'MostRecentDateEnteredFederalContractorJobDVOP',
#  'PIRL1300': 'ReceivedTrainingWIOA',
#  'PIRL1301': 'EligibleTrainingProviderNameTrainingService1WIOA',
#  'PIRL1302': 'DateEnteredTraining1WIOA',
#  'PIRL1303': 'TypeOfTrainingService1WIOA',
#  'PIRL1304': 'EligibleTrainingProviderProgramOfStudyWIOA',
#  'PIRL1305': 'EligibleTrainingProviderCipCodeWIOA',
#  'PIRL1306': 'OccupationalSkillsTrainingCode1',
#  'PIRL1307': 'TrainingCompleted1',
#  'PIRL1308': 'DateCompletedOrWithdrewFromTraining1',
#  'PIRL1309': 'DateEnteredTraining2',
#  'PIRL1310': 'TypeOfTrainingService2WIOA',
#  'PIRL1311': 'OccupationalSkillsTrainingCode2',
#  'PIRL1312': 'TrainingCompleted2',
#  'PIRL1313': 'DateCompletedOrWithdrewFromTraining2',
#  'PIRL1314': 'DateEnteredTraining3',
#  'PIRL1315': 'TypeOfTrainingService3WIOA',
#  'PIRL1316': 'OccupationalSkillsTrainingCode3',
#  'PIRL1317': 'TrainingCompleted3',
#  'PIRL1318': 'DateCompletedOrWithdrewFromTraining3',
#  'PIRL1319': 'EstablishedIndividualTrainingAccountITA',
#  'PIRL1320': 'PellGrantRecipient',
#  'PIRL1321': 'WaiverFromTrainingRequirement',
#  'PIRL1322': 'DateOfMostRecentCaseManagementAndReemploymentServi',
#  'PIRL1323': 'DateWaiverFromTrainingRequirementIssued',
#  'PIRL1324': 'CurrentQuarterTrainingExpenditures',
#  'PIRL1325': 'TotalTrainingExpenditures',
#  'PIRL1326': 'TrainingCostsAmountOfOverpayment',
#  'PIRL1327': 'TrainingCostsOverpaymentWaiver',
#  'PIRL1328': 'DistanceLearning',
#  'PIRL1329': 'PartTimeTraining',
#  'PIRL1330': 'AdverselyAffectedIncumbentWorker',
#  'PIRL1331': 'TrainingLeadingToAnAssociatesDegree',
#  'PIRL1332': 'ParticipatedInPostsecondaryEducationDuringProgramP',
#  'PIRL1333': 'ReceivedTrainingFromProgramsOperatedByThePrivateSe',
#  'PIRL1401': 'EnrolledInSecondaryEducationProgramAtProgramEntryW',
#  'PIRL1402': 'MostRecentDateReceivedEducationalAchievementServic',
#  'PIRL1403': 'MostRecentDateReceivedAlternativeSecondarySchoolSe',
#  'PIRL1405': 'MostRecentDateReceivedWorkExperienceOpportunities',
#  'PIRL1406': 'DateEnrolledInPostExitEducationOrTrainingProgramLe',
#  'PIRL1407': 'MostRecentDateReceivedEducationOfferedConcurrently',
#  'PIRL1408': 'MostRecentDateReceivedLeadershipDevelopmentOpportu',
#  'PIRL1409': 'MostRecentDateReceivedSupportiveServices',
#  'PIRL1410': 'MostRecentDateReceivedAdultMentoringServices',
#  'PIRL1411': 'MostRecentDateReceivedComprehensiveGuidanceCounsel',
#  'PIRL1412': 'MostRecentDateReceivedYouthFollowUpServices',
#  'PIRL1413': 'MostRecentDateYouthReceivedEntrepreneurialSkillsTr',
#  'PIRL1414': 'MostRecentDateYouthReceivedServicesThatProvideLabo',
#  'PIRL1415': 'MostRecentDateYouthReceivedPostsecondaryTransition',
#  'PIRL1416': 'DateOfCompletionOfYouthServices',
#  'PIRL1500': 'ReceivedNeedsRelatedPayments',
#  'PIRL1501': 'MostRecentDateReceivedRapidResponseServices',
#  'PIRL1503': 'MostRecentDateReceivedFollowUpService',
#  'PIRL1505': 'JobSearchAllowanceCountTAA',
#  'PIRL1506': 'JobSearchAllowanceCurrentQuarterCostsTAA',
#  'PIRL1507': 'JobSearchAllowanceTotalCostsTAA',
#  'PIRL1508': 'DateRelocationAllowanceApprovedTAA',
#  'PIRL1509': 'RelocationAllowanceCurrentQuarterCostsTAAv2',
#  'PIRL1510': 'RelocationAllowanceTotalCostTAA',
#  'PIRL1511': 'DateReceivedFirstBasicTRAPayment',
#  'PIRL1512': 'WeeksPaidThisQuarterBasicTRA',
#  'PIRL1513': 'TotalWeeksPaidCumulativeBasicTRA',
#  'PIRL1514': 'AmountPaidCurrentQuarterTRABasic',
#  'PIRL1515': 'TotalAmountPaidBasicTRA',
#  'PIRL1516': 'DateReceivedFirstAdditionalTRAPayment',
#  'PIRL1517': 'WeeksPaidThisQuarterAdditionalTRA',
#  'PIRL1518': 'TotalWeeksPaidCumulativeAdditionalTRA',
#  'PIRL1519': 'AmountPaidThisQuarterAdditionalTRA',
#  'PIRL1520': 'TotalAmountPaidAdditionalTRA',
#  'PIRL1521': 'DateReceivedFirstRemedialPrerequisiteTRAPayment',
#  'PIRL1522': 'WeeksPaidThisQuarterRemedialPrerequisite',
#  'PIRL1523': 'TotalWeeksPaidCumulativeRemedialPrerequisite',
#  'PIRL1524': 'AmountPaidThisQuarterRemedialPrerequisiteTRA',
#  'PIRL1525': 'TotalAmountPaidRemedialPrerequisiteTRA',
#  'PIRL1526': 'DateReceivedFirstCompletionTRAPayment',
#  'PIRL1527': 'WeeksPaidThisQuarterCompletionTRA',
#  'PIRL1528': 'TotalWeeksPaidCumulativeCompletionTRA',
#  'PIRL1529': 'AmountPaidCurrentQuarterTRACompletion',
#  'PIRL1530': 'TotalAmountPaidCompletionTRA',
#  'PIRL1531': 'TRAOverpayment',
#  'PIRL1532': 'AmountOfTRAOverpayment',
#  'PIRL1533': 'TRAOverpaymentWaiver',
#  'PIRL1534': 'DateReceivedFirstARTAAPayment',
#  'PIRL1535': 'NumberOfARTAAPaymentsCurrentQuarter',
#  'PIRL1536': 'CurrentQuarterARTAAPayments',
#  'PIRL1537': 'NumberOfARTAAPaymentsTotal',
#  'PIRL1538': 'TotalAmountPaidARTAA',
#  'PIRL1539': 'FrequencyOfPayments',
#  'PIRL1540': 'MaximumARTAABenefitReached',
#  'PIRL1541': 'ARTAAOverpaymentCurrentQuarter',
#  'PIRL1542': 'AmountOfARTAAOverpayment',
#  'PIRL1543': 'ARTAAOverpaymentWaiver',
#  'PIRL1600': 'EmployedIn1StQuarterAfterExitQuarterWIOA',
#  'PIRL1601': 'TypeOfEmploymentMatch1stQuarterAfterExitQuarterWIO',
#  'PIRL1602': 'EmployedIn2ndQuarterAfterExitQuarterWIOA',
#  'PIRL1603': 'TypeOfEmploymentMatch2ndQuarterAfterExitQuarterWIO',
#  'PIRL1604': 'EmployedIn3rdQuarterAfterExitQuarterWIOA',
#  'PIRL1605': 'TypeOfEmploymentMatch3rdQuarterAfterExitQuarterWIO',
#  'PIRL1606': 'EmployedIn4thQuarterAfterExitQuarterWIOA',
#  'PIRL1607': 'TypeOfEmploymentMatch4thQuarterAfterExitQuarterWIO',
#  'PIRL1608': 'EmploymentRelatedToTraining2ndQuarterAfterExitWIOA',
#  'PIRL1609': 'RecalledByLayoffEmployer',
#  'PIRL1610': 'OccupationalCodeIfAvailable',
#  'PIRL1611': 'EnteredNonTraditionalEmployment',
#  'PIRL1612': 'OccupationalCodeOfEmployment2ndQuarterAfterExitQua',
#  'PIRL1613': 'OccupationalCodeOfEmployment4thQuarterAfterExitQua',
#  'PIRL1614': 'IndustryCodeOfEmployment1stQuarterAfterExitQuarter',
#  'PIRL1615': 'IndustryCodeOfEmployment2ndQuarterAfterExitQuarter',
#  'PIRL1616': 'IndustryCodeOfEmployment3rdQuarterAfterExitQuarter',
#  'PIRL1617': 'IndustryCodeOfEmployment4thQuarterAfterExitQuarter',
#  'PIRL1618': 'RetentionWithTheSameEmployerInThe2ndQuarterAndThe4',
#  'PIRL1700': 'Wages3rdQuarterPriorToParticipationQuarter',
#  'PIRL1701': 'Wages2ndQuarterPriorToParticipationQuarter',
#  'PIRL1702': 'Wages1stQuarterPriorToParticipationQuarter',
#  'PIRL1703': 'Wages1StQuarterAfterExitQuarterWIOA',
#  'PIRL1704': 'Wages2NdQuarterAfterExitQuarterWIOA',
#  'PIRL1705': 'Wages3RdQuarterAfterExitQuarterWIOA',
#  'PIRL1706': 'Wages4ThQuarterAfterExitQuarterWIOA',
#  'PIRL1800': 'TypeOfRecognizedCredentialWIOA',
#  'PIRL1801': 'DateAttainedRecognizedCredentialWIOA',
#  'PIRL1802': 'TypeOfRecognizedCredential2',
#  'PIRL1803': 'DateAttainedRecognizedCredential2',
#  'PIRL1804': 'TypeOfRecognizedCredential3',
#  'PIRL1805': 'DateAttainedRecognizedCredential3',
#  'PIRL1806': 'DateOfMostRecentMeasurableSkillGainsEducationalFun',
#  'PIRL1807': 'DateOfMostRecentMeasurableSkillGainsPostsecondaryT',
#  'PIRL1808': 'DateOfMostRecentMeasurableSkillGainsSecondaryTrans',
#  'PIRL1809': 'DateOfMostRecentMeasurableSkillGainsTrainingMilest',
#  'PIRL1810': 'DateOfMostRecentMeasurableSkillGainsSkillsProgress',
#  'PIRL1811': 'DateEnrolledDuringProgramParticipationInAnEducatio',
#  'PIRL1812': 'SchoolStatusAtExit',
#  'PIRL1813': 'DateCompletedDuringProgramParticipationAnEducation',
#  'PIRL1814': 'DateAttainedGraduatePostGraduateDegreeWIOA',
#  'PIRL1900': 'Youth2ndQuarterPlacementTitleIWIOA',
#  'PIRL1901': 'Youth4thQuarterPlacementTitleIWIOA',
#  'PIRL1902': 'CategoryOfAssessment',
#  'PIRL1903': 'DateOfPreTestScore',
#  'PIRL1904': 'PreTestScore',
#  'PIRL1905': 'EducationalFunctioningLevelPreTest',
#  'PIRL1906': 'DateOfMostRecentPostTestScore',
#  'PIRL1907': 'PostTestScore',
#  'PIRL1908': 'EducationalFunctioningLevelPostTest',
#  'PIRL1909': 'CategoryOfAssessment2',
#  'PIRL1910': 'DateOfPreTestScore2',
#  'PIRL1911': 'PreTestScore2',
#  'PIRL1912': 'EducationalFunctioningLevelPreTest2',
#  'PIRL1913': 'DateOfMostRecentPostTestScore2',
#  'PIRL1914': 'PostTestScore2',
#  'PIRL1915': 'EducationalFunctioningLevelPostTest2',
#  'PIRL1916': 'CategoryOfAssessment3',
#  'PIRL1917': 'DateOfPreTestScore3',
#  'PIRL1918': 'PreTestScore3',
#  'PIRL1919': 'EducationalFunctioningLevelPreTest3',
#  'PIRL1920': 'DateOfMostRecentPostTestScore3',
#  'PIRL1921': 'PostTestScore3',
#  'PIRL1922': 'EducationalFunctioningLevelPostTest3',
#  'PIRL200': 'DateOfBirthWIOA',
#  'PIRL2001': 'DateOfCompletionOfDwgServices',
#  'PIRL2002': 'EmployedAtCompletionOfDwgServices',
#  'PIRL2003': 'DwgGrantNumber',
#  'PIRL2004': 'ReceivedServicesThroughADisasterRecoveryDislocated',
#  'PIRL201': 'Sex',
#  'PIRL202': 'IndividualWithADisabilityWIOA',
#  'PIRL203': 'CategoryOfDisability',
#  'PIRL204': 'IndividualWithADisabilitySDDAServices',
#  'PIRL205': 'IndividualWithADisabilityLSMHAServices',
#  'PIRL206': 'IndividualWithADisabilityMedicaidHCBSServices',
#  'PIRL207': 'IndividualWithADisabilityWorkSetting',
#  'PIRL208': 'IndividualWithADisabilityTypeOfCustomizedEmploymen',
#  'PIRL209': 'IndividualWithADisabilityFinancialCapability',
#  'PIRL210': 'EthnicityHispanicLatinoWIOA',
#  'PIRL2101': 'UnderemployedWorker',
#  'PIRL2102': 'PreviousQuarterReceivedCaseManagementService',
#  'PIRL2103': 'MostRecentDateReceivedAssessmentServices',
#  'PIRL2104': 'PreviousQuarterReceivedAssessmentServices',
#  'PIRL2105': 'PreviousQuarterReceivedSupportiveServices',
#  'PIRL2106': 'MostRecentDateReceivedSpecializedParticipantServic',
#  'PIRL2107': 'PreviousQuarterReceivedSpecializedServices',
#  'PIRL2108': 'PreviousQuarterParticipatedInWorkExperience',
#  'PIRL2109': 'PrimaryTypeOfTrainingServiceForTrainingActivity1',
#  'PIRL211': 'AmericanIndianAlaskaNativeWIOA',
#  'PIRL2110': 'SecondaryTypeOfTrainingServiceForTrainingActivity1',
#  'PIRL2111': 'TertiaryTypeOfTrainingServiceForTrainingActivity1',
#  'PIRL2112': 'PrimaryTypeOfTrainingServiceForTrainingActivity2',
#  'PIRL2113': 'SecondaryTypeOfTrainingServiceForTrainingActivity2',
#  'PIRL2114': 'TertiaryTypeOfTrainingServiceForTrainingActivity2',
#  'PIRL2115': 'PrimaryTypeOfTrainingServiceForTrainingActivity3',
#  'PIRL2116': 'SecondaryTypeOfTrainingServiceForTrainingActivity3',
#  'PIRL2117': 'TertiaryTypeOfTrainingServiceForTrainingActivity3',
#  'PIRL2118': 'DateEnteredEmploymentDiscretionaryGrants',
#  'PIRL2119': 'IncumbentWorkersRetainedCurrentPosition',
#  'PIRL212': 'AsianWIOA',
#  'PIRL2120': 'IncumbentWorkersAdvancedIntoANewPositionWithCurren1',
#  'PIRL2121': 'IncumbentWorkersRetainedCurrentPositionInThe2ndQua',
#  'PIRL2122': 'IncumbentWorkersAdvancedIntoANewPositionWithCurren2',
#  'PIRL2123': 'IncumbentWorkersRetainedCurrentPositionInThe3rdQua',
#  'PIRL2124': 'IncumbentWorkersAdvancedIntoANewPositionWithCurren3',
#  'PIRL2126': 'EnteredTrainingRelatedEmployment',
#  'PIRL213': 'BlackAfricanAmericanWIOA',
#  'PIRL214': 'NativeHawaiianOtherPacificIslanderWIOA',
#  'PIRL215': 'WhiteWIOA',
#  'PIRL2200': 'ForThoseWhoWerePlacedInEmploymentJobCoveredByUnemp',
#  'PIRL2202': 'ForThoseWhoWerePlacedInEmploymentFringeBenefitsAva',
#  'PIRL2203': 'ForThoseWhoWerePlacedInEmploymentHourlyWageAtPlace',
#  'PIRL2204': 'ForThoseWhoWerePlacedInEmploymentHoursWorkedPerWee',
#  'PIRL2205': 'ForThoseWhoWerePlacedInEmploymentSelfEmployment',
#  'PIRL2206': 'ForThoseWhoWerePlacedInEmploymentEnteredMilitarySe',
#  'PIRL2207': 'ForThoseWhoWerePlacedInEmploymentEnteredPreApprent',
#  'PIRL2208': 'CategoryOfExit',
#  'PIRL2209': 'RelatedAssistanceTransportation',
#  'PIRL2210': 'RelatedAssistanceHealthCare',
#  'PIRL2211': 'FamilyCareIncludingChildCare',
#  'PIRL2212': 'RelatedAssistanceHousingAssistanceServices',
#  'PIRL2213': 'RelatedAssistanceNutritionalAssistance',
#  'PIRL2214': 'RelatedAssistanceTranslationAndInterpretationServi',
#  'PIRL2215': 'RelatedAssistanceStaffAssisted',
#  'PIRL2216': 'ReceivedWorkerSafetyTraining',
#  'PIRL2217': 'WorkExperienceFundedBy167Grant',
#  'PIRL2218': 'OnTheJobTrainingOJTFundedBy167Grant',
#  'PIRL2219': 'IntegratedBasicOccupationalSkillsTrainingFundedBy1',
#  'PIRL2220': 'OccupationalSkillsTrainingNonOJTFundedBy167Grant',
#  'PIRL2221': 'BasicSkillsTrainingFundedBy167Grant',
#  'PIRL2222': 'LacksTransportation',
#  'PIRL2223': 'LongTermAgriculturalEmployment',
#  'PIRL2224': 'LacksSignificantWorkHistory',
#  'PIRL2225': 'SixMonthPreProgramEarningsDuring6MonthsPriorToDat',
#  'PIRL2226': 'TotalPreProgramEarningsDuring12MonthEligibilityDet',
#  'PIRL2227': 'NumberOfDependentsInTheFamilyUnderAge18',
#  'PIRL2231': 'DateOfEligibilityDetermination',
#  'PIRL2232': 'FamilyStatusNFJP',
#  'PIRL2233': 'NFJPGrantEnrollment',
#  'PIRL2302': 'TribalAffiliation',
#  'PIRL2303': 'PublicAssistanceRecipient',
#  'PIRL2400': 'InWorkReleaseProgram',
#  'PIRL2401': 'EmploymentStatusAtIncarceration',
#  'PIRL2404': 'AlcoholDrugAbuseAtEnrollment',
#  'PIRL2412': 'CriminalJusticeSystemIdentifier',
#  'PIRL2413': 'IncarceratedAtProgramEntryWIOA',
#  'PIRL2414': 'DateReleasedFromIncarcerationWIOA',
#  'PIRL2415': 'DateOfAnticipatedReleaseFromIncarceration',
#  'PIRL2416': 'PostReleaseStatus',
#  'PIRL2417': 'MostRecentTypeOfOffense',
#  'PIRL2422': 'HousingStatusAtSixMonthsAfterProgramEntry',
#  'PIRL2423': 'HousingStatusAtEnrollment',
#  'PIRL2424': 'AlcoholDrugAbuseSixMonthsAfterEnrollment',
#  'PIRL2433': 'ReArrestedWithin12MonthsOfReleaseForANewCrime',
#  'PIRL2434': 'ReArrestedForAPreviousCrime',
#  'PIRL2435': 'ReIncarceratedForARevocationOfTheParoleOrProbation',
#  'PIRL2436': 'NotReArrested',
#  'PIRL2437': 'DateArrestedForNewPreviousCrime',
#  'PIRL2438': 'ConvictedForNewPreviousCrime',
#  'PIRL2439': 'DateReIncarcerated',
#  'PIRL2440': 'DateChargesDropped',
#  'PIRL2500': 'SecondarySchoolEnrollmentStatusAtArrest',
#  'PIRL2502': 'YouthOffenderStatusAtEnrollment',
#  'PIRL2503': 'DateReleasedFromCorrectionalFacilityOrPlacedOnProb',
#  'PIRL2505': 'DateVerifiedSelectiveServiceRegistration',
#  'PIRL2506': 'VoterRegistration',
#  'PIRL2507': 'DriversLicense',
#  'PIRL2509': 'FirstDateOfService',
#  'PIRL2510': 'CompletedDiversionWithoutOutOfHomePlacement',
#  'PIRL2511': 'RecordsExpunged',
#  'PIRL2512': 'RecordsSealed',
#  'PIRL2516': 'DateOfPostsecondaryEducationOrTrainingPlacement',
#  'PIRL2519': 'HourlyTrainingWage',
#  'PIRL2523': 'DateEnteredDegreeOrCertificateProgram',
#  'PIRL2525': 'DateArrestedForNewCrimeAfterEnrollment',
#  'PIRL2526': 'ConvictedForNewCrimeCommittedAfterEnrollment',
#  'PIRL2527': 'TypeOfCrime',
#  'PIRL2528': 'Reached12MonthPointSinceReleaseFromCorrectionalFac',
#  'PIRL2529': 'ConvictedForNewCrimeCommittedWithin12MonthsOfRelea',
#  'PIRL2530': 'IncarceratedForNewCrimeCommittedAfterEnrollment',
#  'PIRL2541': 'ReceivingPublicAssistanceSinceLeavingTheProgram',
#  'PIRL2542': 'ArrestedForNewCrimeInFollowUpPeriod',
#  'PIRL2543': 'DateArrestedForNewCrimeInFollowUpPeriod',
#  'PIRL2544': 'ConvictedForNewCrimeCommittedInFollowUpPeriod',
#  'PIRL2545': 'IncarceratedForNewCrimeCommittedInFollowUpPeriod',
#  'PIRL2546': 'HousingStatusAtFollowUp',
#  'PIRL2600': 'ConstructionPlusGrantee',
#  'PIRL2603': 'CompletedMentalToughnessComponent',
#  'PIRL2605': 'ChildrenLivingWithParticipant',
#  'PIRL2606': 'OtherDependentsLivingWithParticipant',
#  'PIRL2607': 'MigrantYouth',
#  'PIRL2608': 'Offender',
#  'PIRL2609': 'SecondarySchoolDropOut',
#  'PIRL2610': 'ChildOfIncarceratedParentOrLegalGuardian',
#  'PIRL2611': 'HealthIssues',
#  'PIRL2612': 'OccupationAtEnrollment',
#  'PIRL2613': 'HoursWorkedAtEnrollment',
#  'PIRL2614': 'AverageHourlyWageAtEnrollment',
#  'PIRL2616': 'HousingStatus',
#  'PIRL2700': 'SocialSecurityNumber',
#  'PIRL2701': 'WibName',
#  'PIRL2702': 'OfficeName',
#  'PIRL2703': 'CaseManager',
#  'PIRL2704': 'UserField2',
#  'PIRL2800': 'UrbanRural',
#  'PIRL2801': 'FamilySize',
#  'PIRL2802': 'FamilyIncomePovertyLevel',
#  'PIRL2803': 'VeteranPost911Era',
#  'PIRL2804': 'AtRiskOfHomelessness',
#  'PIRL2805': 'FailedToFindEmploymentAfterReceivingWIOATitleIServ',
#  'PIRL2806': 'LowEmploymentProspects',
#  'PIRL2807': 'SCSEPEligible',
#  'PIRL2808': 'ReasonForIneligibilityRecert',
#  'PIRL2809': 'DateOfRecertificationDetermination',
#  'PIRL2810': 'SevereDisability',
#  'PIRL2811': 'DateOfLastUpdateSevereDisability',
#  'PIRL2812': 'Frailty',
#  'PIRL2813': 'DateOfLastUpdateFrailty',
#  'PIRL2814': 'OldEnoughForButNotReceivingSocialSecurityTitleII',
#  'PIRL2815': 'DateOfLastUpdateOldEnoughForButNotReceivingSocialS',
#  'PIRL2816': 'SeverelyLimitedEmploymentProspectsInAreaOfPersiste',
#  'PIRL2817': 'DateOfLastUpdateSeverelyLimitedEmploymentProspects',
#  'PIRL2818': 'LimitedEnglishProficiency',
#  'PIRL2819': 'DateOfLastUpdateLimitedEnglishProficiency',
#  'PIRL2820': 'LowLiteracySkills',
#  'PIRL2821': 'DateOfLastUpdateLowLiteracySkills',
#  'PIRL2822': 'TypeOfPlacement',
#  'PIRL2824': 'ParticipantReturnedToSCSEPWithinTheFirst90DaysOfEx',
#  'PIRL2825': 'HasTheParticipantReEnrolledInSCSEPWithinTheFirst90',
#  'PIRL2826': 'ApprovedBreakStart',
#  'PIRL2827': 'ApprovedBreakEndDate',
#  'PIRL2828': 'ReasonForApprovedBreakInParticipation',
#  'PIRL2829': 'ParticipantCommunityServiceAssignment',
#  'PIRL2830': 'SupportiveServiceProvider',
#  'PIRL2831': 'WagePerHourCommunityServiceAssignment',
#  'PIRL2832': 'TotalHoursPaidIn1stQuarter',
#  'PIRL2833': 'TotalHoursPaidIn2ndQuarter',
#  'PIRL2834': 'TotalHoursPaidIn3rdQuarter',
#  'PIRL2835': 'TotalHoursPaidIn4thQuarter',
#  'PIRL2836': 'TotalHoursOfPaidTrainingIn1stQuarter',
#  'PIRL2837': 'TotalHoursOfPaidTrainingIn2ndQuarter',
#  'PIRL2838': 'TotalHoursOfPaidTrainingIn3rdQuarter',
#  'PIRL2839': 'TotalHoursOfPaidTrainingIn4thQuarter',
#  'PIRL2840': 'OtherReasonsForExitSCSEPOnly',
#  'PIRL2841': 'ExclusionAfterExit',
#  'PIRL2842': 'DateExclusionOccurred',
#  'PIRL2843': 'HostAgencyEmployer',
#  'PIRL2844': 'EmployerType',
#  'PIRL2845': 'PlacementStartDate',
#  'PIRL2846': 'PlacementEndDate',
#  'PIRL2847': 'SCSEPApplicationDate',
#  'PIRL300': 'VeteranStatus',
#  'PIRL301': 'EligibleVeteranStatus',
#  'PIRL302': 'CampaignVeteran',
#  'PIRL303': 'DisabledVeteran',
#  'PIRL304': 'DateOfActualMilitarySeparation',
#  'PIRL305': 'TransitioningServiceMember',
#  'PIRL306': 'CoveredPersonEntryDate',
#  'PIRL307': 'TAPWorkshopIn3PriorYears',
#  'PIRL308': 'HomelessVeteran',
#  'PIRL309': 'HomelessVeteransReintegrationProgramParticipant',
#  'PIRL310': 'HomelessVeteransReintegrationProgramGrantee',
#  'PIRL311': 'HomelessVeteransReintegrationProgramGrantee2',
#  'PIRL312': 'ReasonTheParticipantIsBeingServedByASecondHVRPGran',
#  'PIRL313': 'HomelessVeteransReintegrationProgramGrantee3',
#  'PIRL314': 'ReasonTheParticipantIsBeingServedByAThirdHVRPGrant',
#  'PIRL315': 'OtherSignificantBarrierToEmployment',
#  'PIRL316': 'ActiveDutyMilitarySpouse',
#  'PIRL400': 'EmploymentStatusAtProgramEntryWIOA',
#  'PIRL401': 'UcEligibleStatus',
#  'PIRL402': 'LongTermUnemployedAtProgramEntryWIOA',
#  'PIRL403': 'OccupationalCodeOfMostRecentEmploymentPriorToParti',
#  'PIRL404': 'IndustryCodeOfEmployment1stQuarterPriorToParticipa',
#  'PIRL405': 'IndustryCodeOfEmployment2ndQuarterPriorToParticipa',
#  'PIRL406': 'IndustryCodeOfEmployment3rdQuarterPriorToParticipa',
#  'PIRL407': 'HighestSchoolGradeCompletedAtProgramEntryWIOA',
#  'PIRL408': 'HighestEducationalLevelCompletedAtProgramEntryWIOA',
#  'PIRL409': 'SchoolStatusAtProgramEntryWIOA',
#  'PIRL410': 'DateOfActualDislocation',
#  'PIRL411': 'MostRecentDateOfQualifyingSeparation',
#  'PIRL412': 'TenureWithEmployerAtSeparation',
#  'PIRL413': 'MigrantAndSeasonalFarmworkerDesignationWagnerPeyse',
#  'PIRL600': 'TemporaryAssistanceToNeedyFamiliesTANF',
#  'PIRL601': 'ExhaustingTanfWithin2YearsPartATitleIvOfTheSocialS',
#  'PIRL602': 'SupplementalSecurityIncomeSsiSocialSecurityDisabil',
#  'PIRL603': 'SupplementalNutritionAssistanceProgramSNAP',
#  'PIRL604': 'OtherPublicAssistanceRecipient',
#  'PIRL701': 'PregnantOrParentingYouth',
#  'PIRL702': 'YouthWhoNeedsAdditionalAssistance',
#  'PIRL704': 'FosterCareYouthStatusAtProgramEntryWIOA',
#  'PIRL800': 'HomelessParticipantHomelessChildrenAndYouthsOrRuna',
#  'PIRL801': 'ExOffenderStatusAtProgramEntryWIOA',
#  'PIRL802': 'LowIncomeStatusAtProgramEntryWIOA',
#  'PIRL803': 'EnglishLanguageLearnerAtProgramEntryWIOA',
#  'PIRL804': 'BasicSkillsDeficientLowLevelsOfLiteracyAtProgramEn',
#  'PIRL805': 'CulturalBarriersAtProgramEntryWIOA',
#  'PIRL806': 'SingleParentAtProgramEntryWIOA',
#  'PIRL807': 'DisplacedHomemakerAtProgramEntryWIOA',
#  'PIRL808': 'MigrantAndSeasonalFarmworkerStatusAtNationalFarmwo',
#  'PIRL900': 'DateOfProgramEntryWIOA',
#  'PIRL901': 'DateOfProgramExitWIOA',
#  'PIRL902': 'DateOfFirstCaseManagementAndEmploymentService',
#  'PIRL903': 'AdultWIOA',
#  'PIRL904': 'DislocatedWorkerWIOA',
#  'PIRL905': 'YouthWIOA',
#  'PIRL906': 'DateOfFirstWIOAYouthService',
#  'PIRL907': 'RecipientOfIncumbentWorkerTraining',
#  'PIRL908': 'RapidResponse',
#  'PIRL909': 'RapidResponseAdditionalAssistance',
#  'PIRL910': 'AdultEducationWIOA',
#  'PIRL911': 'JobCorpsWIOA',
#  'PIRL912': 'NationalFarmworkerJobsProgram',
#  'PIRL913': 'IndianAndNativeAmericanPrograms',
#  'PIRL914': 'VeteransPrograms',
#  'PIRL915': 'TAAPetitionNumber',
#  'PIRL916': 'VocationalEducation',
#  'PIRL917': 'VocationalRehabilitationWIOA',
#  'PIRL918': 'WagnerPeyserEmploymentServiceWIOA',
#  'PIRL919': 'YouthbuildWIOA',
#  'PIRL920': 'SeniorCommunityServiceEmploymentProgram',
#  'PIRL921': 'EmploymentAndTrainingServicesRelatedToSNAP',
#  'PIRL922': 'OtherWioaOrNonWioaPrograms',
#  'PIRL923': 'OtherReasonsForExitWIOA',
#  'PIRL924': 'TAAApplicationDate',
#  'PIRL925': 'DateOfFirstTAABenefitOrService',
#  'PIRL926': 'TAALiableAgentStateIdentifier',
#  'PIRL927': 'TAADateOfEligibilityDetermination',
#  'PIRL928': 'DeterminedEligibleForTAA',
#  'PIRL929': 'BenefitUnderPriorCertificationLast10YearsTAA',
#  'PIRL930': 'PayForPerformance',
#  'PIRL931': 'RegisteredApprenticeshipProgram',
#  'PIRL932': 'NationalDislocatedWorkerGrantsDWG',
#  'PIRL933': 'DateOfFirstDWGService',
#  'PIRL934': 'RapidResponseEventNumber',
#  'PIRL935': 'AccountabilityExitStatus',
#  'PIRL936': 'ReintegrationOfExOffendersAdult',
#  'PIRL937': 'ReintegrationOfExOffendersYouth',
#  'PIRL938': 'H1B',
#  'PIRL939': 'IndividualWithADisabilityIndividualizedEducationPr',
#  'PIRL940': 'IndividualWithADisabilitySection504Plan',
#  'PIRL941': 'NationalFarmworkerJobsProgramNFJP'}

# %%
for i in range( 5 ):
    
    print( stata_list[ i ] )
# Out:
# ********************************************************************************
# *************************QPR TEST AGGREGATION RULES*****************************
# ********************************************************************************
# cd "H:\Data Work\WIPS Test File"
# local cdate: display %td-CY-m-D date(c(current_date),"DMY")

# %% [markdown]
# ### Build Stop List of Translatable Lines

# %%
translatable = [ "local", "count", "replace" ]
translatable
# Out:
# ['local', 'count', 'replace']

# %% [markdown]
# ### Kill Multiple Space Chars

# %%
def kill_extra_spaces( raw_line ):
    
    # replace multiple spaces w/ just one
    return re.sub( ' +', ' ', raw_line )

kill_extra_spaces( "12  23  45               4 4 4 4 4        45 64 6  ASFD     " )
# Out:
# '12 23 45 4 4 4 4 4 45 64 6 ASFD '

# %% [markdown]
# ### Normalize Parenthesis

# %%
def normalize_parenthesis( raw_line ):
    
    # add spaces between parens and chars
    raw_line = re.sub( r'\(', "( ", re.sub( r'\)', " )", raw_line ) )

    return kill_extra_spaces( raw_line )

normalize_parenthesis( "//         putexcel M21 = (r(N)),    sheet(       `report' ) " )
# Out:
# "// putexcel M21 = ( r( N ) ), sheet( `report' ) "

# %% [markdown]
# ### Normalize Plus Signs

# %%
def normalize_plus_signs( raw_line ):
    
    # add spaces between plus signs and chars
    raw_line = re.sub( r'\+', " + ", raw_line )

    return kill_extra_spaces( raw_line )

normalize_plus_signs( "count if ( ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==2 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==3 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==4 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==5 ) ) & `FS' & `total' & `prevpartdef'" )
# Out:
# "count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==2 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==3 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==4 ) | ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 )==5 ) ) & `FS' & `total' & `prevpartdef'"

# %% [markdown]
# ### Normalize Equals Signs

# %%
def normalize_equals( raw_line ):
    
    # add spaces between plus signs and chars
    raw_line = re.sub( r'==', " = ", raw_line )

    return kill_extra_spaces( raw_line )

normalize_equals( "count if ( ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==2 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==3 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==4 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 )==5 ) ) & `FS' & `total' & `prevpartdef'" )
# Out:
# "count if ( ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 ) = 2 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 ) = 3 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 ) = 4 ) | ( ( PIRL211+PIRL212+PIRL213+PIRL214+PIRL215 ) = 5 ) ) & `FS' & `total' & `prevpartdef'"

# %% [markdown]
# ### Translate Conjunctions

# %%
def translate_conjuntions( raw_line ):
    
    # replace | with OR, add spaces between
    raw_line = re.sub( r'\|', " OR ", raw_line )
    
    # replace & with AND, add spaces between
    raw_line = re.sub( r'&', " AND ", raw_line )
    
    return kill_extra_spaces( raw_line )

translate_conjuntions( "replace age = age - 1 if (month(PIRL906) < month(PIRL200)) | (month(PIRL906) == month(PIRL200) & day(PIRL906) < day(PIRL200))" )
# Out:
# 'replace age = age - 1 if (month(PIRL906) < month(PIRL200)) OR (month(PIRL906) == month(PIRL200) AND day(PIRL906) < day(PIRL200))'

# %% [markdown]
# ### Translate Variable Declarations

# %%
def translate_variable_declarations( raw_line ):
    
    raw_line = re.sub( '^local ([A-Za-z0-9]{1,}) "', r'val \1 = "', raw_line )
    
    return kill_extra_spaces( raw_line )

translate_variable_declarations( 'local Adult "( inlist( PIRL903,1,2,3,4 ) )' )
# Out:
# 'val Adult = "( inlist( PIRL903,1,2,3,4 ) )'

# %% [markdown]
# ### Translate 'IN' clauses

# %%
def translate_in_clause( raw_line ):
    
    # WORKS: raw_line = re.sub( r'(PIRL[0-9]{1,3})', r'__1st__\1__1st__', raw_line )
    # WORKS: raw_line = re.sub( r'inlist\(', 'MATCH', raw_line )
    # WORKS: raw_line = re.sub( r'(inlist)', r'--YEP--\1--YEP--', raw_line )
    # WO$RKS: raw_line = re.sub( r'(inlist\() (PIRL[0-9]{1,3},)', r'1st:[\1] 2nd: [\2]', raw_line )
    raw_line = re.sub( r'(inlist\() (PIRL[0-9]{1,3})', r'\2 IN (', raw_line )
    
    # kludgey, but it works: replace " IN (," with " IN ( "
    raw_line = re.sub( r' IN \(,', r' IN ( ', raw_line )
    
    return kill_extra_spaces( raw_line )

translate_in_clause( "( inlist( PIRL903,1,2,3,4 ) )" )
# Out:
# '( PIRL903 IN ( 1,2,3,4 ) )'

# %% [markdown]
# ### Translate Date Variable Declarations

# %%
# declare month abbreviations to numerics as a dictionary
months = {}
months[ "jan" ] = "01"
months[ "feb" ] = "02"
months[ "mar" ] = "03"
months[ "apr" ] = "04"
months[ "may" ] = "05"
months[ "jun" ] = "06"
months[ "jul" ] = "07"
months[ "aug" ] = "08"
months[ "sep" ] = "09"
months[ "oct" ] = "10"
months[ "nov" ] = "11"
months[ "dec" ] = "12"

def substitute_months( match ):
    
    return 'val {} = "{}-{}-{}"'.format( match.group( 1 ), match.group( 4 ), months[ match.group( 3 ) ], match.group( 2 ) )

def translate_date_vars( raw_line ):
    
    # This line calls a function w/ the match object.  ¡Genial!
    # Here: https://stackoverflow.com/questions/17136127/calling-a-function-on-captured-group-in-re-sub
    raw_line = re.sub( r'local ([a-zA-Z0-9]{1,}) (\d\d)([a-zA-Z]{3})(\d\d\d\d)', substitute_months, raw_line )
    
    # Plain, w/o month abbreviation to numeric lookup
    #raw_line = re.sub( r'local ([a-zA-Z]{1,}) (\d\d)([a-zA-Z]{3})(\d\d\d\d)', r'var \1 = "\4-\3-\2"', raw_line )
    
    return kill_extra_spaces( raw_line )

translate_date_vars( "local begpart2date 01oct2017" )
# Out:
# 'val begpart2date = "2017-10-01"'

# %% [markdown]
# ### Translate "d( var )" to "to_date( '$date_var' )"

# %%
def translate_date_function( raw_line ):
    
    raw_line = re.sub( r" d\( `([A-Za-z0-9]{1,})' \) ", r" to_date( '$\1' ) ", raw_line )
    
    return kill_extra_spaces( raw_line )

translate_date_function( "( PIRL900 <= d( `qtrend' ) )" )
# Out:
# "( PIRL900 <= to_date( '$qtrend' ) )"

# %%
for line in stata_list:
    
    words = line.split( " " )
    if words[ 0 ] in translatable:
        
        line = normalize_parenthesis( line )
        line = normalize_plus_signs( line )
        line = normalize_equals( line )
        line = translate_conjuntions( line )
        line = translate_variable_declarations( line )
        line = translate_in_clause( line )
        line = translate_date_vars( line )
        line = translate_date_function( line )
        
        print( line )
        
    else:
        print( "// " + line )
# Out:
# // ********************************************************************************
# // *************************QPR TEST AGGREGATION RULES*****************************
# // ********************************************************************************
# // cd "H:\Data Work\WIPS Test File"
# local cdate: display %td-CY-m-D date( c( current_date ),"DMY" )
# // copy "QPR_Template.xlsx" "StataQPROutput`cdate'.xlsx", replace
# // set more off
# // putexcel clear
# // putexcel set "StataQPROutput`cdate'.xlsx", modify keepcellformat
# // ************FUNDING STREAMS*****************************************************
# val Adult = "( PIRL903 IN ( 1,2,3,4 ) )"
# val DW = "( PIRL904 IN ( 1,2,3,4 ) OR PIRL909 = 1 )"
# val WP = "( PIRL918 IN ( 1,2 ) )"
# val Youth = "( PIRL905 IN ( 1,2,3,4 ) )"
# // ************PARTICIPANT AND REPORTABLE INDIVIDUAL SPLITS************************
# val partsplit = "( PIRL903 IN ( 1,2,3 ) OR PIRL904 IN ( 1,2,3 ) OR PIRL918 IN ( 1 ) OR PIRL905 IN ( 1,2,3 ) )"
# val risplit = "( PIRL903 IN ( 4 ) OR PIRL904 IN ( 4 ) OR PIRL918 IN ( 2 ) OR PIRL905 IN ( 4 ) )"
# // ********Reporting Periods for Quarter Ending 12/31/17  ROLLING 4 QTRS************
# // **Current Period**
# val begpartdate = "2017-10-01"
# val qtrend = "2018-09-30"
# val begexitdate = "2017-07-01"
# val endexitdate = "2018-06-30"
# val beginq2date = "2016-10-01"
# val endq2date = "2017-09-30"
# val beginq4date = "2016-07-01"
# val endq4date = "2016-03-31"
# // **Previous Period**
# val prevbegpartdate = "2017-07-01"
# val prevqtrend = "2018-06-30"
# val prevbegexitdate = "2017-04-01"
# val prevendexitdate = "2018-03-31"
# val prevbeginq2date = "2016-07-01"
# val prevendq2date = "2017-06-30"
# val prevbeginq4date = "2016-07-01"
# val prevendq4date = "2016-12-31"
# // ***********Participant, Exiter and Reportable Individual Defintitions***********
# val partdef = "( `partsplit' AND ( PIRL900 <= to_date( '$qtrend' ) ) AND ( ( PIRL901 >= to_date( '$begpartdate' ) ) OR missing( PIRL901 ) ) )"
# val prevpartdef = "( `partsplit' AND ( PIRL900 <= to_date( '$prevqtrend' ) ) AND ( ( PIRL901 >= to_date( '$prevbegpartdate' ) ) OR missing( PIRL901 ) ) )"
# val exitdef = "( `partsplit' AND ( PIRL901 >= to_date( '$begexitdate' ) AND PIRL901 <= to_date( '$endexitdate' ) AND !missing( PIRL901 ) ) )"
# val prevexitdef = "( `partsplit' AND ( PIRL901 >= to_date( '$prevbegexitdate' ) AND PIRL901 <= to_date( '$prevendexitdate' ) AND !missing( PIRL901 ) ) )"
# val reptind = "( `risplit' AND ( !missing( PIRL1002 ) AND PIRL1002 >= to_date( '$begpartdate' ) AND PIRL1002 <= to_date( '$qtrend' ) ) OR ( !missing( PIRL1007 ) AND PIRL1007 >= to_date( '$begpartdate' ) AND PIRL1007 <= to_date( '$qtrend' ) ) )"
# val prevreptind = "( `risplit' AND ( !missing( PIRL1002 ) AND PIRL1002 >= to_date( '$prevbegpartdate' ) AND PIRL1002 <= to_date( '$prevqtrend' ) ) OR ( !missing( PIRL1007 ) AND PIRL1007 >= to_date( '$prevbegpartdate' ) AND PIRL1007 <= to_date( '$prevqtrend' ) ) )"
# // ****************Youth Participant and Exiter Defintitions***********************
# val ythexitdef = "( `partsplit' AND PIRL901 >= to_date( '$begexitdate' ) AND PIRL901 <= to_date( '$endexitdate' ) AND !missing( PIRL906 ) )"
# val ythprevexitdef = "( `partsplit' AND PIRL901 >= to_date( '$prevbegexitdate' ) AND PIRL901 <= to_date( '$prevendexitdate' ) AND !missing( PIRL906 ) )"
# val ythpartdef = "( `partsplit' AND PIRL900 <= to_date( '$qtrend' ) ) AND ( ( PIRL901 >= to_date( '$begpartdate' ) ) OR missing( PIRL901 ) )"
# val ythprevpartdef = "( `partsplit' AND PIRL900 <= to_date( '$prevqtrend' ) ) AND ( ( PIRL901 >= to_date( '$prevbegpartdate' ) ) OR missing( PIRL901 ) )"
# // ******************Services Defintitions*****************************************
# val bcsvc = "( !missing( PIRL1001 ) AND missing( PIRL1200 ) AND PIRL1300 != 1 )"
# val icsvc = "( !missing( PIRL1200 ) AND PIRL1300 != 1 )"
# val tsvc = "( PIRL1300 = 1 )"
# val total = "( !missing( PIRL1001 ) OR !missing( PIRL1200 ) OR PIRL1300 = 1 )"
# // ******************Youth Services Defintitions***********************************
# val notoccsvc = "( !missing( PIRL906 ) AND PIRL1300 != 1 )"
# val occsvc = "( !missing( PIRL906 ) AND PIRL1300 = 1 )"
# val ythtotal = "( !missing( PIRL906 ) )"
# // *****************Performance Indicator Definitions******************************
# val empq2den = "( `partsplit' AND !missing( PIRL900 ) AND !missing( PIRL901 ) AND PIRL901 >= to_date( '$beginq2date' ) AND PIRL901 <= to_date( '$endq2date' ) AND PIRL923 = 0 )"
# val empq2num = "( `empq2den' AND PIRL1602 > 0 AND PIRL1602 < 9 )"
# val ythq2num = "( `empq2den' AND ( ( PIRL1602 > 0 AND PIRL1602 < 9 ) OR ( PIRL1900 > 0 AND !missing( PIRL1900 ) ) ) )"
# val empq4den = "( `partsplit' AND !missing( PIRL900 ) AND !missing( PIRL901 ) AND PIRL901 >= to_date( '$beginq4date' ) AND PIRL901 <= to_date( '$endq4date' ) AND PIRL923 = 0 )"
# val empq4num = "( `empq4den' AND PIRL1606 > 0 AND PIRL1606 < 9 )"
# val ythq4num = "( `empq4den' AND ( ( PIRL1606 > 0 AND PIRL1606 < 9 ) OR ( PIRL1901 > 0 AND !missing( PIRL1901 ) ) ) )"
# val meq2 = "( `partsplit' AND PIRL1704 > 0 AND PIRL1704 < 999999.99 AND !missing( PIRL1704 ) AND !missing( PIRL900 ) AND PIRL901 >= to_date( '$beginq2date' ) AND PIRL901 <= to_date( '$endq2date' ) AND PIRL923 = 0 )"
# val credden = "( `partsplit' AND !missing( PIRL900 ) AND PIRL901 >= to_date( '$beginq4date' ) AND PIRL901 <= to_date( '$endq4date' ) AND ( ( PIRL130 IN (3,2,3,4,6,7,8,9,10 ) OR PIRL131 IN (0,2,3,4,6,7,8,9,10 ) OR PIRL131 IN (5,2,3,4,6,7,8,9,10 ) ) OR PIRL1332 = 1 OR ( PIRL408 = 0 AND PIRL1401 = 1 ) ) AND PIRL923 = 0 )"
# val crednum = "( `credden' AND ( ( ( !missing( PIRL1801 ) AND ( PIRL1801 - PIRL901 <= 365 ) AND PIRL180 IN (0,2,3,4,5,6,7 ) ) OR ( !missing( PIRL1803 ) AND ( PIRL1803 - PIRL901 <= 365 ) AND PIRL180 IN (2,2,3,4,5,6,7 ) ) OR ( !missing( PIRL1805 ) AND ( PIRL1805 - PIRL901 <= 365 ) AND PIRL180 IN (4,2,3,4,5,6,7 ) ) ) OR ( ( ( !missing( PIRL1801 ) AND ( PIRL1801 - PIRL901 <= 365 ) AND PIRL180 IN (0,1 ) ) OR ( !missing( PIRL1803 ) AND ( PIRL1803 - PIRL901 <= 365 ) AND PIRL180 IN (2,1 ) ) OR ( !missing( PIRL1805 ) AND ( PIRL1805 - PIRL901 <= 365 ) AND PIRL180 IN (4,1 ) ) ) AND ( ( !missing( PIRL1406 ) AND ( PIRL1406 - PIRL901 <= 365 ) ) OR ( PIRL160 IN (0,1,2,3 ) ) OR ( PIRL160 IN (2,1,2,3 ) ) OR ( PIRL160 IN (4,1,2,3 ) ) OR ( PIRL160 IN (6,1,2,3 ) ) ) ) ) )"
# val msgden = "( `partsplit' AND !missing( PIRL900 ) AND PIRL900 <= to_date( '$qtrend' ) AND ( missing( PIRL901 ) OR ( PIRL901 >= to_date( '$begpartdate' ) AND PIRL901 <= to_date( '$qtrend' ) ) ) AND !missing( PIRL1811 ) AND ( missing( PIRL1813 ) OR ( PIRL1813 >= to_date( '$begpartdate' ) AND PIRL1813 <= to_date( '$qtrend' ) ) ) AND ( PIRL923 IN ( 0,7,. ) ) )"
# val msgnum = "( `msgden' AND ( ( PIRL1806 >= to_date( '$begpartdate' ) AND PIRL1806 <= to_date( '$qtrend' ) ) OR ( ( PIRL1801 >= to_date( '$begpartdate' ) AND PIRL1801 <= to_date( '$qtrend' ) ) AND PIRL1800 = 1 ) OR ( ( PIRL1803 >= to_date( '$begpartdate' ) AND PIRL1803 <= to_date( '$qtrend' ) ) AND PIRL1802 = 1 ) OR ( ( PIRL1805 >= to_date( '$begpartdate' ) AND PIRL1805 <= to_date( '$qtrend' ) ) AND PIRL1804 = 1 ) OR ( PIRL1807 >= to_date( '$begpartdate' ) AND PIRL1807 <= to_date( '$qtrend' ) ) OR ( PIRL1808 >= to_date( '$begpartdate' ) AND PIRL1808 <= to_date( '$qtrend' ) ) OR ( PIRL1809 >= to_date( '$begpartdate' ) AND PIRL1809 <= to_date( '$qtrend' ) ) OR ( PIRL1810 >= to_date( '$begpartdate' ) AND PIRL1810 <= to_date( '$qtrend' ) ) ) )"
# // **************Previous Period Performance Indicator Definitions*****************
# val prevempq2den = "( `partsplit' AND !missing( PIRL900 ) AND !missing( PIRL901 ) AND PIRL901 >= to_date( '$prevbeginq2date' ) AND PIRL901 <= to_date( '$prevendq2date' ) AND PIRL923 = 0 )"
# val prevempq2num = "( `empq2den' AND PIRL1602 > 0 AND PIRL1602 < 9 )"
# val prevythq2num = "( `empq2den' AND ( ( PIRL1602 > 0 AND PIRL1602 < 9 ) OR ( PIRL1900 > 0 AND !missing( PIRL1900 ) ) ) )"
# val prevempq4den = "( `partsplit' AND !missing( PIRL900 ) AND !missing( PIRL901 ) AND PIRL901 >= to_date( '$prevbeginq4date' ) AND PIRL901 <= to_date( '$prevendq4date' ) AND PIRL923 = 0 )"
# val prevempq4num = "( `empq4den' AND PIRL1606 > 0 AND PIRL1606 < 9 )"
# val prevythq4num = "( `empq4den' AND ( ( PIRL1606 > 0 AND PIRL1606 < 9 ) OR ( PIRL1901 > 0 AND !missing( PIRL1901 ) ) ) )"
# val prevmeq2 = "( `partsplit' AND PIRL1704 > 0 AND PIRL1704 < 999999.99 AND !missing( PIRL1704 ) AND !missing( PIRL900 ) AND PIRL901 >= to_date( '$prevbeginq2date' ) AND PIRL901 <= to_date( '$prevendq2date' ) AND PIRL923 = 0 )"
# val prevcredden = "( `partsplit' AND !missing( PIRL900 ) AND PIRL901 >= to_date( '$prevbeginq4date' ) AND PIRL901 <= to_date( '$prevendq4date' ) AND ( ( PIRL130 IN (3,2,3,4,6,7,8,9,10 ) OR PIRL131 IN (0,2,3,4,6,7,8,9,10 ) OR PIRL131 IN (5,2,3,4,6,7,8,9,10 ) ) OR PIRL1332 = 1 OR ( PIRL408 = 0 AND PIRL1401 = 1 ) ) AND PIRL923 = 0 )"
# val prevcrednum = "( `credden' AND ( ( ( !missing( PIRL1801 ) AND ( PIRL1801 - PIRL901 <= 365 ) AND PIRL180 IN (0,2,3,4,5,6,7 ) ) OR ( !missing( PIRL1803 ) AND ( PIRL1803 - PIRL901 <= 365 ) AND PIRL180 IN (2,2,3,4,5,6,7 ) ) OR ( !missing( PIRL1805 ) AND ( PIRL1805 - PIRL901 <= 365 ) AND PIRL180 IN (4,2,3,4,5,6,7 ) ) ) OR ( ( ( !missing( PIRL1801 ) AND ( PIRL1801 - PIRL901 <= 365 ) AND PIRL180 IN (0,1 ) ) OR ( !missing( PIRL1803 ) AND ( PIRL1803 - PIRL901 <= 365 ) AND PIRL180 IN (2,1 ) ) OR ( !missing( PIRL1805 ) AND ( PIRL1805 - PIRL901 <= 365 ) AND PIRL180 IN (4,1 ) ) ) AND ( ( !missing( PIRL1406 ) AND ( PIRL1406 - PIRL901 <= 365 ) ) OR ( PIRL160 IN (0,1,2,3 ) ) OR ( PIRL160 IN (2,1,2,3 ) ) OR ( PIRL160 IN (4,1,2,3 ) ) OR ( PIRL160 IN (6,1,2,3 ) ) ) ) ) )"
# val prevmsgden = "( `partsplit' AND !missing( PIRL900 ) AND PIRL900 <= to_date( '$prevqtrend' ) AND ( missing( PIRL901 ) OR ( PIRL901 >= to_date( '$prevbegpartdate' ) AND PIRL901 <= to_date( '$prevqtrend' ) ) ) AND !missing( PIRL1811 ) AND ( missing( PIRL1813 ) OR ( PIRL1813 >= to_date( '$prevbegpartdate' ) AND PIRL1813 <= to_date( '$prevqtrend' ) ) ) AND ( PIRL923 IN ( 0,7,. ) ) )"
# val prevmsgnum = "( `msgden' AND ( ( PIRL1806 >= to_date( '$prevbegpartdate' ) AND PIRL1806 <= to_date( '$prevqtrend' ) ) OR ( ( PIRL1801 >= to_date( '$prevbegpartdate' ) AND PIRL1801 <= to_date( '$prevqtrend' ) ) AND PIRL1800 = 1 ) OR ( ( PIRL1803 >= to_date( '$prevbegpartdate' ) AND PIRL1803 <= to_date( '$prevqtrend' ) ) AND PIRL1802 = 1 ) OR ( ( PIRL1805 >= to_date( '$prevbegpartdate' ) AND PIRL1805 <= to_date( '$prevqtrend' ) ) AND PIRL1804 = 1 ) OR ( PIRL1807 >= to_date( '$prevbegpartdate' ) AND PIRL1807 <= to_date( '$prevqtrend' ) ) OR ( PIRL1808 >= to_date( '$prevbegpartdate' ) AND PIRL1808 <= to_date( '$prevqtrend' ) ) OR ( PIRL1809 >= to_date( '$prevbegpartdate' ) AND PIRL1809 <= to_date( '$prevqtrend' ) ) OR ( PIRL1810 >= to_date( '$prevbegpartdate' ) AND PIRL1810 <= to_date( '$prevqtrend' ) ) ) )"
# // ********************************************************************************
# //
# // **Set up Age calcs
# // capture noisily drop age
# // gen age = year(PIRL900) - year(PIRL200)
# replace age = age - 1 if ( month( PIRL900 ) < month( PIRL200 ) ) OR ( month( PIRL900 ) = month( PIRL200 ) AND day( PIRL900 ) < day( PIRL200 ) )
# // **
# //
# // *FS STORAGE: "(inlist(PIRL903,1,2,3,4))" "(inlist(PIRL904,1,2,3,4) | PIRL909 == 1)" "(inlist(PIRL918,1,2))" "(inlist(PIRL905,1,2,3,4))"
# // foreach FS in "(inlist(PIRL903,1,2,3,4))" "(inlist(PIRL904,1,2,3,4) | PIRL909 == 1)" "(inlist(PIRL918,1,2))" "(inlist(PIRL905,1,2,3,4))" {
# //
# // **Name the excel sheet
# // if "`FS'" == "`Adult'" {
# // macro drop report
# val report = "WIOA_Adult"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // if "`FS'" == "`DW'" {
# // macro drop report
# val report = "WIOA_DW"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // if "`FS'" == "`WP'" {
# // macro drop report
# val report = "Wagner-Peyser"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // if "`FS'" == "`Youth'" {
# // macro drop report
# val report = "WIOA_Youth"
# // display _newline
# // display "**********Running " "`report'" " Report**********"
# // display _newline
# // }
# // **Title the report by funding stream
# // putexcel B3 = ("`qtrend' Performance Report for `report'"), sheet(`report')
# //
# // //////////////**********"Adult" QPR Specs********///////////////////////////////
# //
# // if "`FS'" != "`Youth'" {
# //
# // ***Section A - Summary Information**********************************************
# //
# // *Only Participants included in these counts*
# //
# // *A.1 Total Exiters*
# // **Total Exiters -- Basic Career Services**
# count if `FS' AND `bcsvc' AND `exitdef'
# // putexcel I9 = (r(N)), sheet(`report')
# //
# // **Total Exiters -- Individualized Career Services**
# count if `FS' AND `icsvc' AND `exitdef'
# // putexcel J9 = (r(N)), sheet(`report')
# //
# // **Total Exiters -- Training Services**
# count if `FS' AND `tsvc' AND `exitdef'
# // putexcel K9 = (r(N)), sheet(`report')
# //
# // **Total Exiters -- Total Current Period**
# count if `FS' AND `total' AND `exitdef'
# // putexcel L9 = (r(N)), sheet(`report')
# //
# // **Total Exiters -- Total Previous Period**
# count if `FS' AND `total' AND `prevexitdef'
# // putexcel M9 = (r(N)), sheet(`report')
# //
# // *A.2 Total Participants*
# //
# // **Total Participants Served -- Basic Career Services**
# count if `FS' AND `bcsvc' AND `partdef'
# // putexcel I10 = (r(N)), sheet(`report')
# //
# // *Total Participants Served -- Individualized Career Services**
# count if `FS' AND `icsvc' AND `partdef'
# // putexcel J10 = (r(N)), sheet(`report')
# //
# // **Total Participants Served -- Training Services**
# count if `FS' AND `tsvc' AND `partdef'
# // putexcel K10 = (r(N)), sheet(`report')
# //
# // **Total Participants Served -- Total Current Period**
# count if `FS' AND `total' AND `partdef'
# // putexcel L10 = (r(N)), sheet(`report')
# //
# // **Total Participants Served -- Total Previous Period**
# count if `FS' AND `total' AND `prevpartdef'
# // putexcel M10 = (r(N)), sheet(`report')
# //
# //
# // *Only Reportable Individuals included in these counts*
# //
# // *A.3 Total Reportable Individuals*
# //
# // **Total Reportable Individuals -- Total Current Period**
# count if `FS' AND `reptind'
# // putexcel L11 = (r(N)), sheet(`report')
# //
# // **Total Reportable Individuals -- Total Previous Period**
# count if `FS' AND `prevreptind'
# // putexcel M11 = (r(N)), sheet(`report')
# //
# //
# // *Only Participants included in these counts*
# //
# // ***Section B - Participant Summary and Service Information**********************
# //
# // **********************Basic Career Services*************************************
# // *1a. Male*
# count if PIRL201 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I13 = (r(N)), sheet(`report')
# // *1b. Female
# count if PIRL201 = 2 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I14 = (r(N)), sheet(`report')
# // *2a. Hispanic/Latino
# count if PIRL210 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I15 = (r(N)), sheet(`report')
# // *2b. American Indian or Alaskan Native
# count if PIRL211 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I16 = (r(N)), sheet(`report')
# // *2c. Asian
# count if PIRL212 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I17 = (r(N)), sheet(`report')
# // *2d. Black or African American
# count if PIRL213 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I18 = (r(N)), sheet(`report')
# // *2e. Native Hawaiian or Other Pacific Islander
# count if PIRL214 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I19 = (r(N)), sheet(`report')
# // *2f. White
# count if PIRL215 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I20 = (r(N)), sheet(`report')
# // *2g. More Than One Race
# count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 2 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 3 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 4 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 5 ) ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I21 = (r(N)), sheet(`report')
# // *3a. Eligible Veterans
# count if ( PIRL301 > 1 AND !missing( PIRL301 ) ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I22 = (r(N)), sheet(`report')
# // *3b. Individuals with a Disability
# count if PIRL202 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I23 = (r(N)), sheet(`report')
# // *3c. Incumbent Workers
# count if ( PIRL907 > 0 AND !missing( PIRL907 ) ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I24 = (r(N)), sheet(`report')
# // *3d. Unemployed Individuals
# count if ( PIRL400 = 0 OR PIRL400 = 2 OR PIRL400 = 3 ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I25 = (r(N)), sheet(`report')
# // *4a. Secondary School Graduate or Equivalent
# count if ( PIRL408 = 1 OR PIRL408 = 2 ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I26 = (r(N)), sheet(`report')
# // *4b. Completed 1 or more years of Postsecondary Education
# count if PIRL408 = 4 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I27 = (r(N)), sheet(`report')
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
# count if PIRL408 = 5 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I28 = (r(N)), sheet(`report')
# // *4d. Associate's Degree
# count if PIRL408 = 6 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I29 = (r(N)), sheet(`report')
# // *4e. Bachelor's Degree or Equivalent
# count if PIRL408 = 7 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I30 = (r(N)), sheet(`report')
# // *4f. Advanced Degree Beyond Bachelor's Degree
# count if PIRL408 = 8 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I31 = (r(N)), sheet(`report')
# //
# // ***********************Individualized Career Services***************************
# // *1a. Male*
# count if PIRL201 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J13 = (r(N)), sheet(`report')
# // *1b. Female
# count if PIRL201 = 2 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J14 = (r(N)), sheet(`report')
# // *2a. Hispanic/Latino
# count if PIRL210 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J15 = (r(N)), sheet(`report')
# // *2b. American Indian or Alaskan Native
# count if PIRL211 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J16 = (r(N)), sheet(`report')
# // *2c. Asian
# count if PIRL212 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J17 = (r(N)), sheet(`report')
# // *2d. Black or African American
# count if PIRL213 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J18 = (r(N)), sheet(`report')
# // *2e. Native Hawaiian or Other Pacific Islander
# count if PIRL214 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J19 = (r(N)), sheet(`report')
# // *2f. White
# count if PIRL215 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J20 = (r(N)), sheet(`report')
# // *2g. More Than One Race
# count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 2 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 3 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 4 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 5 ) ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J21 = (r(N)), sheet(`report')
# // *3a. Eligible Veterans
# count if ( PIRL301 > 1 AND !missing( PIRL301 ) ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J22 = (r(N)), sheet(`report')
# // *3b. Individuals with a Disability
# count if PIRL202 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J23 = (r(N)), sheet(`report')
# // *3c. Incumbent Workers
# count if ( PIRL907 > 0 AND !missing( PIRL907 ) ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J24 = (r(N)), sheet(`report')
# // *3d. Unemployed Individuals
# count if ( PIRL400 = 0 OR PIRL400 = 2 OR PIRL400 = 3 ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J25 = (r(N)), sheet(`report')
# // *4a. Secondary School Graduate or Equivalent
# count if ( PIRL408 = 1 OR PIRL408 = 2 ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J26 = (r(N)), sheet(`report')
# // *4b. Completed 1 or more years of Postsecondary Education
# count if PIRL408 = 4 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J27 = (r(N)), sheet(`report')
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
# count if PIRL408 = 5 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J28 = (r(N)), sheet(`report')
# // *4d. Associate's Degree
# count if PIRL408 = 6 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J29 = (r(N)), sheet(`report')
# // *4e. Bachelor's Degree or Equivalent
# count if PIRL408 = 7 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J30 = (r(N)), sheet(`report')
# // *4f. Advanced Degree Beyond Bachelor's Degree
# count if PIRL408 = 8 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J31 = (r(N)), sheet(`report')
# //
# // *******************************Training Services********************************
# // *1a. Male*
# count if PIRL201 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K13 = (r(N)), sheet(`report')
# // *1b. Female
# count if PIRL201 = 2 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K14 = (r(N)), sheet(`report')
# // *2a. Hispanic/Latino
# count if PIRL210 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K15 = (r(N)), sheet(`report')
# // *2b. American Indian or Alaskan Native
# count if PIRL211 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K16 = (r(N)), sheet(`report')
# // *2c. Asian
# count if PIRL212 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K17 = (r(N)), sheet(`report')
# // *2d. Black or African American
# count if PIRL213 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K18 = (r(N)), sheet(`report')
# // *2e. Native Hawaiian or Other Pacific Islander
# count if PIRL214 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K19 = (r(N)), sheet(`report')
# // *2f. White
# count if PIRL215 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K20 = (r(N)), sheet(`report')
# // *2g. More Than One Race
# count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 2 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 3 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 4 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 5 ) ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K21 = (r(N)), sheet(`report')
# // *3a. Eligible Veterans
# count if ( PIRL301 > 1 AND !missing( PIRL301 ) ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K22 = (r(N)), sheet(`report')
# // *3b. Individuals with a Disability
# count if PIRL202 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K23 = (r(N)), sheet(`report')
# // *3c. Incumbent Workers
# count if ( PIRL907 > 0 AND !missing( PIRL907 ) ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K24 = (r(N)), sheet(`report')
# // *3d. Unemployed Individuals
# count if ( PIRL400 = 0 OR PIRL400 = 2 OR PIRL400 = 3 ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K25 = (r(N)), sheet(`report')
# // *4a. Secondary School Graduate or Equivalent
# count if ( PIRL408 = 1 OR PIRL408 = 2 ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K26 = (r(N)), sheet(`report')
# // *4b. Completed 1 or more years of Postsecondary Education
# count if PIRL408 = 4 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K27 = (r(N)), sheet(`report')
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
# count if PIRL408 = 5 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K28 = (r(N)), sheet(`report')
# // *4d. Associate's Degree
# count if PIRL408 = 6 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K29 = (r(N)), sheet(`report')
# // *4e. Bachelor's Degree or Equivalent
# count if PIRL408 = 7 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K30 = (r(N)), sheet(`report')
# // *4f. Advanced Degree Beyond Bachelor's Degree
# count if PIRL408 = 8 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K31 = (r(N)), sheet(`report')
# //
# // ********************Total Current Period****************************************
# // *1a. Male*
# count if PIRL201 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L13 = (r(N)), sheet(`report')
# // *1b. Female
# count if PIRL201 = 2 AND `FS' AND `total' AND `partdef'
# // putexcel L14 = (r(N)), sheet(`report')
# // *2a. Hispanic/Latino
# count if PIRL210 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L15 = (r(N)), sheet(`report')
# // *2b. American Indian or Alaskan Native
# count if PIRL211 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L16 = (r(N)), sheet(`report')
# // *2c. Asian
# count if PIRL212 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L17 = (r(N)), sheet(`report')
# // *2d. Black or African American
# count if PIRL213 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L18 = (r(N)), sheet(`report')
# // *2e. Native Hawaiian or Other Pacific Islander
# count if PIRL214 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L19 = (r(N)), sheet(`report')
# // *2f. White
# count if PIRL215 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L20 = (r(N)), sheet(`report')
# // *2g. More Than One Race
# count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 2 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 3 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 4 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 5 ) ) AND `FS' AND `total' AND `partdef'
# // putexcel L21 = (r(N)), sheet(`report')
# // *3a. Eligible Veterans
# count if ( PIRL301 > 1 AND !missing( PIRL301 ) ) AND `FS' AND `total' AND `partdef'
# // putexcel L22 = (r(N)), sheet(`report')
# // *3b. Individuals with a Disability
# count if PIRL202 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L23 = (r(N)), sheet(`report')
# // *3c. Incumbent Workers
# count if ( PIRL907 > 0 AND !missing( PIRL907 ) ) AND `FS' AND `total' AND `partdef'
# // putexcel L24 = (r(N)), sheet(`report')
# // *3d. Unemployed Individuals
# count if ( PIRL400 = 0 OR PIRL400 = 2 OR PIRL400 = 3 ) AND `FS' AND `total' AND `partdef'
# // putexcel L25 = (r(N)), sheet(`report')
# // *4a. Secondary School Graduate or Equivalent
# count if ( PIRL408 = 1 OR PIRL408 = 2 ) AND `FS' AND `total' AND `partdef'
# // putexcel L26 = (r(N)), sheet(`report')
# // *4b. Completed 1 or more years of Postsecondary Education
# count if PIRL408 = 4 AND `FS' AND `total' AND `partdef'
# // putexcel L27 = (r(N)), sheet(`report')
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
# count if PIRL408 = 5 AND `FS' AND `total' AND `partdef'
# // putexcel L28 = (r(N)), sheet(`report')
# // *4d. Associate's Degree
# count if PIRL408 = 6 AND `FS' AND `total' AND `partdef'
# // putexcel L29 = (r(N)), sheet(`report')
# // *4e. Bachelor's Degree or Equivalent
# count if PIRL408 = 7 AND `FS' AND `total' AND `partdef'
# // putexcel L30 = (r(N)), sheet(`report')
# // *4f. Advanced Degree Beyond Bachelor's Degree
# count if PIRL408 = 8 AND `FS' AND `total' AND `partdef'
# // putexcel L31 = (r(N)), sheet(`report')
# //
# // **********************Total Previous Period*************************************
# // *1a. Male*
# count if PIRL201 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M13 = (r(N)), sheet(`report')
# // *1b. Female
# count if PIRL201 = 2 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M14 = (r(N)), sheet(`report')
# // *2a. Hispanic/Latino
# count if PIRL210 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M15 = (r(N)), sheet(`report')
# // *2b. American Indian or Alaskan Native
# count if PIRL211 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M16 = (r(N)), sheet(`report')
# // *2c. Asian
# count if PIRL212 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M17 = (r(N)), sheet(`report')
# // *2d. Black or African American
# count if PIRL213 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M18 = (r(N)), sheet(`report')
# // *2e. Native Hawaiian or Other Pacific Islander
# count if PIRL214 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M19 = (r(N)), sheet(`report')
# // *2f. White
# count if PIRL215 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M20 = (r(N)), sheet(`report')
# // *2g. More Than One Race
# count if ( ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 2 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 3 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 4 ) OR ( ( PIRL211 + PIRL212 + PIRL213 + PIRL214 + PIRL215 ) = 5 ) ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M21 = (r(N)), sheet(`report')
# // *3a. Eligible Veterans
# count if ( PIRL301 > 1 AND !missing( PIRL301 ) ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M22 = (r(N)), sheet(`report')
# // *3b. Individuals with a Disability
# count if PIRL202 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M23 = (r(N)), sheet(`report')
# // *3c. Incumbent Workers
# count if ( PIRL907 > 0 AND !missing( PIRL907 ) ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M24 = (r(N)), sheet(`report')
# // *3d. Unemployed Individuals
# count if ( PIRL400 = 0 OR PIRL400 = 2 OR PIRL400 = 3 ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M25 = (r(N)), sheet(`report')
# // *4a. Secondary School Graduate or Equivalent
# count if ( PIRL408 = 1 OR PIRL408 = 2 ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M26 = (r(N)), sheet(`report')
# // *4b. Completed 1 or more years of Postsecondary Education
# count if PIRL408 = 4 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M27 = (r(N)), sheet(`report')
# // *4c. Postsecondary Certification, License, or Educational Certificate (non-degree)
# count if PIRL408 = 5 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M28 = (r(N)), sheet(`report')
# // *4d. Associate's Degree
# count if PIRL408 = 6 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M29 = (r(N)), sheet(`report')
# // *4e. Bachelor's Degree or Equivalent
# count if PIRL408 = 7 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M30 = (r(N)), sheet(`report')
# // *4f. Advanced Degree Beyond Bachelor's Degree
# count if PIRL408 = 8 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M31 = (r(N)), sheet(`report')
# //
# // ***Section C - Employment Barrier***********************************************
# //
# // **********************Basic Career Services*************************************
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I33 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I34 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I35 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I36 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I37 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND age >= 14 AND age <=24 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I38 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I39 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I40 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I41 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I42 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `bcsvc' AND `partdef'
# // putexcel I43 = (r(N)), sheet(`report')
# //
# // **********************Individualized Career Services****************************
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J33 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J34 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J35 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J36 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J37 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND age >= 14 AND age <=24 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J38 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J39 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `icsvc' AND `partdef'
# // putexcel J40 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J41 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J42 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `icsvc' AND `partdef'
# // putexcel J43 = (r(N)), sheet(`report')
# //
# // ***********************Training Services****************************************
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K33 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K34 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K35 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K36 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K37 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND age >= 14 AND age <=24 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K38 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K39 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `tsvc' AND `partdef'
# // putexcel K40 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K41 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K42 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `tsvc' AND `partdef'
# // putexcel K43 = (r(N)), sheet(`report')
# //
# // ***********************Total Current Period*************************************
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L33 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L34 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `total' AND `partdef'
# // putexcel L35 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L36 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L37 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND age >= 14 AND age <=24 AND `FS' AND `total' AND `partdef'
# // putexcel L38 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `total' AND `partdef'
# // putexcel L39 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `total' AND `partdef'
# // putexcel L40 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L41 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L42 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `total' AND `partdef'
# // putexcel L43 = (r(N)), sheet(`report')
# //
# // ***********************Total Previous Period*************************************
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M33 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M34 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M35 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M36 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M37 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND age >= 14 AND age <=24 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M38 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M39 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `total' AND `prevpartdef'
# // putexcel M40 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M41 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M42 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `total' AND `prevpartdef'
# // putexcel M43 = (r(N)), sheet(`report')
# //
# // ***Section D - Primary Indicators of Performance********************************
# //
# // *D.1 Employment Rate (Q2)*
# //
# // **Employment Rate (Q2) -- Basic Career Services**
# count if `FS' AND `bcsvc' AND `empq2num'
# // scalar BCq2num = r(N)
# count if `FS' AND `bcsvc' AND `empq2den'
# // scalar BCq2den = r(N)
# // putexcel I52 = (BCq2num/BCq2den), sheet(`report')
# //
# // **Employment Rate (Q2) -- Individualized Career Services**
# count if `FS' AND `icsvc' AND `empq2num'
# // scalar ICq2num = r(N)
# count if `FS' AND `icsvc' AND `empq2den'
# // scalar ICq2den = r(N)
# // putexcel J52 = (ICq2num/ICq2den), sheet(`report')
# //
# // **Employment Rate (Q2) -- Training Services**
# count if `FS' AND `tsvc' AND `empq2num'
# // scalar TSq2num = r(N)
# count if `FS' AND `tsvc' AND `empq2den'
# // scalar TSq2den = r(N)
# // putexcel K52 = (TSq2num/TSq2den), sheet(`report')
# //
# // **Employment Rate (Q2) -- Total Current Period**
# count if `FS' AND `total' AND `empq2num'
# // scalar TCq2num = r(N)
# count if `FS' AND `total' AND `empq2den'
# // scalar TCq2den = r(N)
# // putexcel L52 = (TCq2num/TCq2den), sheet(`report')
# //
# // **Employment Rate (Q2) -- Total Previous Period**
# count if `FS' AND `total' AND `prevempq2num'
# // scalar TPq2num = r(N)
# count if `FS' AND `total' AND `prevempq2den'
# // scalar TPq2den = r(N)
# // putexcel M52 = (TPq2num/TPq2den), sheet(`report')
# //
# //
# // *D.2 Employment Rate (Q4)*
# //
# // **Employment Rate (Q4) -- Basic Career Services**
# count if `FS' AND `bcsvc' AND `empq4num'
# // scalar BCq4num = r(N)
# count if `FS' AND `bcsvc' AND `empq4den'
# // scalar BCq4den = r(N)
# // putexcel I53 = (BCq4num/BCq4den), sheet(`report')
# //
# // **Employment Rate (Q4) -- Individualized Career Services**
# count if `FS' AND `icsvc' AND `empq4num'
# // scalar ICq4num = r(N)
# count if `FS' AND `icsvc' AND `empq4den'
# // scalar ICq4den = r(N)
# // putexcel J53 = (ICq4num/ICq4den), sheet(`report')
# //
# // **Employment Rate (Q4) -- Training Services**
# count if `FS' AND `tsvc' AND `empq4num'
# // scalar TSq4num = r(N)
# count if `FS' AND `tsvc' AND `empq4den'
# // scalar TSq4den = r(N)
# // putexcel K53 = (TSq4num/TSq4den), sheet(`report')
# //
# // **Employment Rate (Q4) -- Total Current Period**
# count if `FS' AND `total' AND `empq4num'
# // scalar TCq4num = r(N)
# count if `FS' AND `total' AND `empq4den'
# // scalar TCq4den = r(N)
# // putexcel L53 = (TCq4num/TCq4den), sheet(`report')
# //
# // **Employment Rate (Q4) -- Total Previous Period**
# count if `FS' AND `total' AND `empq4num'
# // scalar TPq4num = r(N)
# count if `FS' AND `total' AND `empq4den'
# // scalar TPq4den = r(N)
# // putexcel M53 = (TPq4num/TPq4den), sheet(`report')
# //
# //
# // *D.3 Median Earnings*
# //
# // **Median Earnings -- Basic Career Services**
# // capture noisily sum PIRL1704 if `FS' & `bcsvc' & `meq2', detail
# // putexcel I54 = (r(p50)), sheet(`report')
# //
# // **Median Earnings -- Individualized Career Services**"
# // capture noisily sum PIRL1704 if `FS' & `icsvc' & `meq2', detail
# // putexcel J54 = (r(p50)), sheet(`report')
# //
# // **Median Earnings -- Training Services**
# // capture noisily sum PIRL1704 if `FS' & `tsvc' & `meq2', detail
# // putexcel K54 = (r(p50)), sheet(`report')
# //
# // **Median Earnings -- Total Current Period**
# // capture noisily sum PIRL1704 if `FS' & `total' & `meq2', detail
# // putexcel L54 = (r(p50)), sheet(`report')
# //
# // **Median Earnings -- Total Previous Period**
# // capture noisily sum PIRL1704 if `FS' & `total' & `prevmeq2', detail
# // putexcel M54 = (r(p50)), sheet(`report')
# //
# //
# // *D.4 Credential Rate*
# // *Not run for Wagner-Peyser
# //
# // if "`FS'" != "`WP'" {
# // **Credential Rate -- Training Services**
# count if `FS' AND `tsvc' AND `crednum'
# // scalar TScrnum = r(N)
# count if `FS' AND `tsvc' AND `credden'
# // scalar TScrden = r(N)
# // putexcel K55 = (TScrnum/TScrden), sheet(`report')
# //
# // **Credential Rate -- Total Current Period**
# count if `FS' AND `total' AND `crednum'
# // scalar TCcrnum = r(N)
# count if `FS' AND `total' AND `credden'
# // scalar TCcrden = r(N)
# // putexcel L55 = (TCcrnum/TCcrden), sheet(`report')
# //
# // **Credential Rate -- Total Previous Period**
# count if `FS' AND `total' AND `prevcrednum'
# // scalar TPcrnum = r(N)
# count if `FS' AND `total' AND `prevcredden'
# // scalar TPcrden = r(N)
# // putexcel M55 = (TPcrnum/TPcrden), sheet(`report')
# //
# // }
# //
# // *D.5 Measurable Skill Gains*
# // *Not run for Wagner-Peyser
# //
# // if "`FS'" != "`WP'" {
# // **Measurable Skill Gains -- Individualized Career Services**
# count if `FS' AND `icsvc' AND `msgnum'
# // scalar ICmsgnum = r(N)
# count if `FS' AND `icsvc' AND `msgden'
# // scalar ICmsgden = r(N)
# // putexcel J56 = (ICmsgnum/ICmsgden), sheet(`report')
# //
# // **Measurable Skill Gains -- Training Services**
# count if `FS' AND `tsvc' AND `msgnum'
# // scalar TSmsgnum = r(N)
# count if `FS' AND `tsvc' AND `msgden'
# // scalar TSmsgden = r(N)
# // putexcel K56 = (TSmsgnum/TSmsgden), sheet(`report')
# //
# // **Measurable Skill Gains -- Total Current Period**
# count if `FS' AND `total' AND `msgnum'
# // scalar TCmsgnum = r(N)
# count if `FS' AND `total' AND `msgden'
# // scalar TCmsgden = r(N)
# // putexcel L56 = (TCmsgnum/TCmsgden), sheet(`report')
# //
# // **Measurable Skill Gains -- Total Previous Period**
# count if `FS' AND `total' AND `prevmsgnum'
# // scalar TPmsgnum = r(N)
# count if `FS' AND `total' AND `prevmsgden'
# // scalar TPmsgden = r(N)
# // putexcel M56 = (TPmsgnum/TPmsgden), sheet(`report')
# //
# // }
# //
# // ***Section E - Veterans' Priority of Service************************************
# //
# // *E.1 Total Covered Entrants Who Reached the End of the Entry Period*
# // **Total Covered Entrants Who Reached the End of the Entry Period -- Total Covered Entrants**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) )
# // scalar VPOSden = r(N)
# // putexcel K60 = (r(N)), sheet(`report')
# //
# // *E.2 Total Covered Entrants Who Received a Service During the Entry Period*
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Total Covered Entrants*
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) ) AND ( ( !missing( PIRL1000 ) AND ( PIRL1000 - PIRL306 ) <= 45 ) OR ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 ) )
# // scalar VPOS2num = r(N)
# // putexcel K61 = (r(N)), sheet(`report')
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Percent Served Current Period**
# // putexcel L61 = (VPOS2num/VPOSden), sheet(`report')
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Percent Served Previous Period**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) ) AND ( ( !missing( PIRL1000 ) AND ( PIRL1000 - PIRL306 ) <= 45 ) OR ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 ) )
# // scalar VPOS2pnum = r(N)
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) )
# // scalar VPOS2pden = r(N)
# // putexcel M61 = (VPOS2pnum/VPOS2pden), sheet(`report')
# //
# // *E.3 Covered Entrants Who Received a Staff-Assisted Service During the Entry Period*
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Total Covered Entrants**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) ) AND ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 <= 45 ) )
# // scalar VPOS3num = r(N)
# // putexcel K62 = (r(N)), sheet(`report')
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Percent Served Current Period**
# // putexcel L62 = (VPOS3num/VPOSden), sheet(`report')
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Percent Served Previous Period**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) ) AND ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 <= 45 ) )
# // scalar VPOS3pnum = r(N)
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) )
# // scalar VPOS3pden = r(N)
# // putexcel M62 = (VPOS3pnum/VPOS3pden), sheet(`report')
# //
# // }
# // //////////////**********"Youth" QPR Specs********///////////////////////////////
# //
# // if "`FS'" == "`Youth'" {
# //
# // **Set up Youth Age calcs
# // capture noisily drop age
# // gen age = year(PIRL906) - year(PIRL200)
# replace age = age - 1 if ( month( PIRL906 ) < month( PIRL200 ) ) OR ( month( PIRL906 ) = month( PIRL200 ) AND day( PIRL906 ) < day( PIRL200 ) )
# // **
# //
# // ***Section A - Summary Information**********************************************
# //
# // *Only Participants included in these counts*
# //
# // ************************************************************A.1 Total Exiters***
# //
# // **Total Exiters -- Received Services Other Than Occupational Skill Training**
# count if `FS' AND `notoccsvc' AND `ythexitdef'
# // putexcel I10 = (r(N)), sheet(`report')
# //
# // **Total Exiters -- Received Occupational Skills Training Services**
# count if `FS' AND `occsvc' AND `ythexitdef'
# // putexcel J10 = (r(N)), sheet(`report')
# //
# // **Total Exiters -- Total Current Period**
# count if `FS' AND `ythtotal' AND `ythexitdef'
# // putexcel K10 = (r(N)), sheet(`report')
# //
# // **Total Exiters -- Total Previous Period**
# count if `FS' AND `ythtotal' AND `ythprevexitdef'
# // putexcel L10 = (r(N)), sheet(`report')
# //
# ...
# // putexcel I44 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `notoccsvc' AND `ythpartdef'
# // putexcel I45 = (r(N)), sheet(`report')
# //
# // ************Youth Participants Who Have Received Occupational Skills Training***
# //
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J35 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J36 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J37 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J38 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J39 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND `FS' AND `occsvc' AND `partdef'
# // putexcel J40 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J41 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J42 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J43 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J44 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `occsvc' AND `ythpartdef'
# // putexcel J45 = (r(N)), sheet(`report')
# //
# // ***************************************************Youth Total Current Period***
# //
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K35 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K36 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K37 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K38 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K39 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND `FS' AND `ythtotal' AND `partdef'
# // putexcel K40 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K41 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K42 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K43 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K44 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `ythtotal' AND `ythpartdef'
# // putexcel K45 = (r(N)), sheet(`report')
# //
# // **************************************************Youth Total Previous Period***
# //
# // *1. Displaced homemakers
# count if PIRL807 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L35 = (r(N)), sheet(`report')
# // *2. Low-income individuals
# count if PIRL802 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L36 = (r(N)), sheet(`report')
# // *3. Older individuals
# count if ( age >= 55 ) AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L37 = (r(N)), sheet(`report')
# // *4. Ex-offenders
# count if PIRL801 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L38 = (r(N)), sheet(`report')
# // *5. Homeless individuals or runaway youth
# count if PIRL800 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L39 = (r(N)), sheet(`report')
# // *6. Current or former foster care youth
# count if PIRL704 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L40 = (r(N)), sheet(`report')
# // *7. English language learners, individuals with low levels of literacy or facing substantial cultural barriers
# count if ( PIRL805 = 1 OR PIRL803 = 1 OR PIRL804 = 1 ) AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L41 = (r(N)), sheet(`report')
# // *8. Eligible migrant and seasonal farmworkers
# count if ( PIRL808 > 0 AND !missing( PIRL808 ) ) AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L42 = (r(N)), sheet(`report')
# // *9. Exhausting TANF within 2 years (Part A Title IV of the Social Security Act)
# count if PIRL601 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L43 = (r(N)), sheet(`report')
# // *10. Single parents (Including single pregnant women)
# count if PIRL806 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L44 = (r(N)), sheet(`report')
# // *11. Long-term unemployed (27 or more consecutive weeks)
# count if PIRL402 = 1 AND `FS' AND `ythtotal' AND `ythprevpartdef'
# // putexcel L45 = (r(N)), sheet(`report')
# //
# // ***Section D - Primary Indicators of Performance********************************
# //
# // *************************************D.1 Youth Employment/Placement Rate (Q2)***
# //
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Received Services Other Than Occupational Skills Training**
# count if `FS' AND `notoccsvc' AND `ythq2num'
# // scalar NOythq2num = r(N)
# count if `FS' AND `notoccsvc' AND `empq2den'
# // scalar NOythq2den = r(N)
# // putexcel I55 = (NOythq2num/NOythq2den), sheet(`report')
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Youth Participants Who Have Received Occupational Skills Training**
# count if `FS' AND `occsvc' AND `ythq2num'
# // scalar OSythq2num = r(N)
# count if `FS' AND `occsvc' AND `empq2den'
# // scalar OSythq2den = r(N)
# // putexcel J55 = (OSythq2num/OSythq2den), sheet(`report')
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Youth Total Current Period**
# count if `FS' AND `ythtotal' AND `ythq2num'
# // scalar TCythq2num = r(N)
# count if `FS' AND `ythtotal' AND `empq2den'
# // scalar TCythq2den = r(N)
# // putexcel K55 = (TCythq2num/TCythq2den), sheet(`report')
# //
# // **Employment, Education, or Training Placement Rate (Q2) -- Youth Total Previous Period**
# count if `FS' AND `ythtotal' AND `prevythq2num'
# // scalar TPythq2num = r(N)
# count if `FS' AND `ythtotal' AND `prevempq2den'
# // scalar TPythq2den = r(N)
# // putexcel L55 = (TPythq2num/TPythq2den), sheet(`report')
# //
# // *************************************D.2 Youth Employment/Placement Rate (Q4)***
# //
# // **Employment, Education, or Training Placement Rate (Q4) -- Received Services Other Than Occupational Skills Training**
# count if `FS' AND `notoccsvc' AND `ythq4num'
# // scalar NOythq4num = r(N)
# count if `FS' AND `notoccsvc' AND `empq4den'
# // scalar NOythq4den = r(N)
# // putexcel I56 = (NOythq4num/NOythq4den), sheet(`report')
# //
# // **Employment, Education, or Training Placement Rate (Q4) -- Youth Participants Who Have Received Occupational Skills Training**
# count if `FS' AND `occsvc' AND `ythq4num'
# // scalar OSythq4num = r(N)
# count if `FS' AND `occsvc' AND `empq4den'
# // scalar OSythq4den = r(N)
# // putexcel J56 = (OSythq4num/OSythq4den), sheet(`report')
# //
# // **Employment, Education, or Training Placement Rate (Q4) -- Youth Total Current Period**
# count if `FS' AND `ythtotal' AND `ythq4num'
# // scalar TCythq4num = r(N)
# count if `FS' AND `ythtotal' AND `empq4den'
# // scalar TCythq4den = r(N)
# // putexcel K56 = (TCythq4num/TCythq4den), sheet(`report')
# // /*
# // **Employment, Education, or Training Placement Rate (Q4) -- Youth Total Previous Period**
# count if `FS' AND `ythtotal' AND `prevythq4num'
# // scalar TPythq4num = r(N)
# count if `FS' AND `ythtotal' AND `prevempq4den'
# // scalar TPythq4den = r(N)
# // putexcel L56 = (TPythq4num/TPythq4den), sheet(`report')
# // */
# // **********************************************************D.3 Median Earnings***
# //
# // **Median Earnings -- Received Services Other Than Occupational Skills Training**
# // capture noisily sum PIRL1704 if `FS' & `notoccsvc' & `meq2', detail
# // putexcel I57 = (r(p50)), sheet(`report')
# //
# // **Median Earnings -- Youth Participants Who Have Received Occupational Skills Training**"
# // capture noisily sum PIRL1704 if `FS' & `occsvc' & `meq2', detail
# // putexcel J57 = (r(p50)), sheet(`report')
# //
# // **Median Earnings -- Youth Total Current Period**
# // capture noisily sum PIRL1704 if `FS' & `ythtotal' & `meq2', detail
# // putexcel K57 = (r(p50)), sheet(`report')
# //
# // **Median Earnings -- Youth Total Previous Period**
# // capture noisily sum PIRL1704 if `FS' & `ythtotal' & `prevmeq2', detail
# // putexcel L57 = (r(p50)), sheet(`report')
# //
# // **********************************************************D.4 Credential Rate***
# //
# // **Credential Rate -- Received Services Other Than Occupational Skills Training**
# count if `FS' AND `notoccsvc' AND `crednum'
# // scalar NOythcrednum = r(N)
# count if `FS' AND `notoccsvc' AND `credden'
# // scalar NOythcredden = r(N)
# // putexcel I58 = (NOythcrednum/NOythcredden), sheet(`report')
# //
# // **Credential Rate -- Youth Participants Who Have Received Occupational Skills Training**
# count if `FS' AND `occsvc' AND `crednum'
# // scalar OSythcrednum = r(N)
# count if `FS' AND `occsvc' AND `credden'
# // scalar OSythcredden = r(N)
# // putexcel J58 = (OSythcrednum/OSythcredden), sheet(`report')
# //
# // **Credential Rate -- Youth Total Current Period**
# count if `FS' AND `ythtotal' AND `crednum'
# // scalar TCythcrednum = r(N)
# count if `FS' AND `ythtotal' AND `credden'
# // scalar TCythcredden = r(N)
# // putexcel K58 = (TCythcrednum/TCythcredden), sheet(`report')
# // /*
# // **Credential Rate -- Youth Total Previous Period**
# count if `FS' AND `ythtotal' AND `prevcrednum'
# // scalar TPythcrednum = r(N)
# count if `FS' AND `ythtotal' AND `prevcredden'
# // scalar TPythcredden = r(N)
# // putexcel L58 = (TPythcrednum/TPythcredden), sheet(`report')
# // */
# // ***************************************************D.5 Measurable Skill Gains***
# //
# // **Measurable Skill Gains -- Received Services Other Than Occupational Skills Training**
# count if `FS' AND `notoccsvc' AND `msgnum'
# // scalar NOythmsgnum = r(N)
# count if `FS' AND `notoccsvc' AND `msgden'
# // scalar NOythmsgden = r(N)
# // putexcel I59 = (NOythmsgnum/NOythmsgden), sheet(`report')
# //
# // **Measurable Skill Gains -- Youth Participants Who Have Received Occupational Skills Training**
# count if `FS' AND `occsvc' AND `msgnum'
# // scalar OSythmsgnum = r(N)
# count if `FS' AND `occsvc' AND `msgden'
# // scalar OSythmsgden = r(N)
# // putexcel J59 = (OSythmsgnum/OSythmsgden), sheet(`report')
# //
# // **Measurable Skill Gains -- Youth Total Current Period**
# count if `FS' AND `ythtotal' AND `msgnum'
# // scalar TCythmsgnum = r(N)
# count if `FS' AND `ythtotal' AND `msgden'
# // scalar TCythmsgden = r(N)
# // putexcel K59 = (TCythmsgnum/TCythmsgden), sheet(`report')
# //
# // **Measurable Skill Gains -- Youth Total Previous Period**
# count if `FS' AND `ythtotal' AND `prevmsgnum'
# // scalar TPythmsgnum = r(N)
# count if `FS' AND `ythtotal' AND `prevmsgden'
# // scalar TPythmsgden = r(N)
# // putexcel L59 = (TPythmsgnum/TPythmsgden), sheet(`report')
# //
# // ***Section E - Veterans' Priority of Service************************************
# //
# // ***********E.1 Total Covered Entrants Who Reached the End of the Entry Period***
# //
# // **Total Covered Entrants Who Reached the End of the Entry Period -- Total Covered Entrants**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) )
# // putexcel J63 = (r(N)), sheet(`report')
# //
# // ****E.2 Total Covered Entrants Who Received a Service During the Entry Period***
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Total Covered Entrants*
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) ) AND ( ( !missing( PIRL1000 ) AND ( PIRL1000 - PIRL306 ) <= 45 ) OR ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 ) )
# // putexcel J64 = (r(N)), sheet(`report')
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Percent Served Current Period**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) ) AND ( ( !missing( PIRL1000 ) AND ( PIRL1000 - PIRL306 ) <= 45 ) OR ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 ) )
# // scalar VPOS2ythnum = r(N)
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) )
# // scalar VPOS2ythden = r(N)
# // putexcel K64 = (VPOS2ythnum/VPOS2ythden), sheet(`report')
# //
# // **Total Covered Entrants Who Received a Service During the Entry Period -- Percent Served Previous Period**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) ) AND ( ( !missing( PIRL1000 ) AND ( PIRL1000 - PIRL306 ) <= 45 ) OR ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 ) )
# // scalar VPOS2pythnum = r(N)
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) )
# // scalar VPOS2pythden = r(N)
# // putexcel L64 = (VPOS2pythnum/VPOS2pythden), sheet(`report')
# //
# // *E.3 Covered Entrants Who Received a Staff-Assisted Service During the Entry Period***
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Total Covered Entrants**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) ) AND ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 )
# // putexcel J65 = (r(N)), sheet(`report')
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Percent Served Current Period**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) ) AND ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 )
# // scalar VPOS3ythnum = r(N)
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$begpartdate' ) AND PIRL306 <= to_date( '$qtrend' ) )
# // scalar VPOS3ythden = r(N)
# // putexcel K65 = (VPOS3ythnum/VPOS3ythden), sheet(`report')
# //
# // **Covered Entrants Who Received a Staff-Assisted Service During the Entry Period -- Percent Served Previous Period**
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) ) AND ( !missing( PIRL900 ) AND ( PIRL900 - PIRL306 ) <= 45 )
# // scalar VPOS3pythnum = r(N)
# count if `FS' AND PIRL301 IN ( 1,2,3 ) AND ( PIRL306 >= to_date( '$prevbegpartdate' ) AND PIRL306 <= to_date( '$prevqtrend' ) )
# // scalar VPOS3pythden = r(N)
# // putexcel L65 = (VPOS3pythnum/VPOS3pythden), sheet(`report')
# //
# // }
# //
# // display _newline
# // display "*********** " "`report'" " Complete **********"
# // display _newline
# // }
# // ********************************************************************************
# // *********************************END OF REPORT**********************************
# // ********************************************************************************

# %%
foo = stata_list[ 0 ]
print( foo )
# Out:
# ********************************************************************************
